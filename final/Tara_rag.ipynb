# %% [markdown]
# DEPENDENCIES INSTALLATION

# %%
# %%bash
# apt-get install -y libpango-1.0-0 libcairo2
# pip install -q haystack-ai
# pip install -q "datasets>=2.6.1"
# pip install -q "sentence-transformers>=2.2.0"
# pip install -q google-generativeai
# pip install -q google-ai-haystack
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# libcairo2 is already the newest version (1.16.0-5ubuntu2).
# libcairo2 set to manually installed.
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libpango-1.0-0 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 680.2/680.2 kB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.1/201.1 kB 14.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 4.7 MB/s eta 0:00:00

# %%
# !pip install -q streamlit==1.37 streamlit-colab
# !pip install -q reportlab
# !pip install -q weasyprint
# !pip install -q markdown2
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 79.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 85.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 91.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 6.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.26.0 requires tenacity<10.0.0,>=9.0.0, but you have tenacity 8.5.0 which is incompatible.
# google-adk 1.26.0 requires watchdog<7.0.0,>=6.0.0, but you have watchdog 4.0.2 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 31.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.8/319.8 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 57.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.4/829.4 kB 37.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 2.7 MB/s eta 0:00:00

# %% [markdown]
# LIBRARY IMPORTS

# %%
# ========== 1. IMPORTS ==========
import os, json
from getpass import getpass
from haystack import Pipeline, Document
from haystack.document_stores.in_memory import InMemoryDocumentStore
from haystack.components.embedders import SentenceTransformersDocumentEmbedder, SentenceTransformersTextEmbedder
from haystack.components.retrievers.in_memory import InMemoryEmbeddingRetriever
from haystack.components.builders import PromptBuilder
from haystack_integrations.components.generators.google_ai import GoogleAIGeminiGenerator

print("✅ Imports complete.")
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)
# ✅ Imports complete.

# %% [markdown]
# SETUP EMBEDDER AND RETRIEVER

# %%
# ========== 2. COMPONENT SETUP ==========

document_store = InMemoryDocumentStore()
print("🧠 InMemoryDocumentStore initialized.")

doc_embedder = SentenceTransformersDocumentEmbedder(model="sentence-transformers/all-MiniLM-L6-v2")
text_embedder = SentenceTransformersTextEmbedder(model="sentence-transformers/all-MiniLM-L6-v2")

doc_embedder.warm_up()
print("✅ Document and Text embedders initialized and warmed up.")

# retriever = InMemoryEmbeddingRetriever(document_store)
retriever = InMemoryEmbeddingRetriever(document_store=document_store,top_k=40)
print("🔍 Retriever created and connected to document store.")
# Out:
# 🧠 InMemoryDocumentStore initialized.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ✅ Document and Text embedders initialized and warmed up.
# 🔍 Retriever created and connected to document store.

# %% [markdown]
# Data Ingestion(cybersecurity standards + threat framework)

# %%
# ==============================
# DATA INGESTION PIPELINE
# ==============================

import json
import xml.etree.ElementTree as ET
from lxml import etree
from haystack import Document
from collections import Counter


# ==============================
# MITRE ATT&CK (Mobile + ICS)
# ==============================

def ingest_mitre(path, source):
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)

    docs = []
    for obj in data.get("objects", []):
        if obj.get("type") == "attack-pattern":
            name = obj.get("name", "")
            desc = obj.get("description", "")

            if not desc:
                continue

            docs.append(
                Document(
                    content=f"MITRE Technique: {name}\nDescription: {desc}",
                    meta={
                        "source": source,
                        "stix_id": obj.get("id")
                    }
                )
            )
    return docs


mitre_docs = []
mitre_docs += ingest_mitre("mobile-attack (1).json", "MITRE_MOBILE")
mitre_docs += ingest_mitre("ics-attack (1).json", "MITRE_ICS")


# ==============================
# ATM
# ==============================

def ingest_atm(path):
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)

    docs = []
    for obj in data.get("objects", []):
        if obj.get("type") == "attack-pattern":
            name = obj.get("name", "")
            desc = obj.get("description", "")

            if not desc:
                continue

            docs.append(
                Document(
                    content=f"ATM Technique: {name}\nDescription: {desc}",
                    meta={
                        "source": "ATM",
                        "stix_id": obj.get("id")
                    }
                )
            )
    return docs


atm_docs = ingest_atm("latest atm.json")


# ==============================
# CAPEC
# ==============================

def ingest_capec(xml_path):
    tree = ET.parse(xml_path)
    root = tree.getroot()

    ns = {"capec": "http://capec.mitre.org/capec-3"}
    docs = []

    for ap in root.findall(".//capec:Attack_Pattern", ns):
        capec_id = ap.get("ID")
        name = ap.findtext("capec:Name", default="", namespaces=ns)
        desc = ap.findtext("capec:Description", default="", namespaces=ns)

        if not desc:
            continue

        docs.append(
            Document(
                content=f"CAPEC-{capec_id}: {name}\nDescription: {desc}",
                meta={
                    "source": "CAPEC",
                    "capec_id": capec_id
                }
            )
        )
    return docs


capec_docs = ingest_capec("capec_v3.9.xml")


# ==============================
# CWE
# ==============================

def ingest_cwe(xml_path):
    parser = etree.XMLParser(recover=True, huge_tree=True)
    tree = etree.parse(xml_path, parser)
    root = tree.getroot()

    ns = {"cwe": "http://cwe.mitre.org/cwe-7"}
    docs = []

    for w in root.findall(".//cwe:Weakness", namespaces=ns):
        cwe_id = w.get("ID")
        name = w.get("Name")

        desc_elem = w.find("cwe:Description", namespaces=ns)
        desc = desc_elem.text if desc_elem is not None else ""

        if not desc:
            continue

        docs.append(
            Document(
                content=f"CWE-{cwe_id}: {name}\nDescription: {desc}",
                meta={
                    "source": "CWE",
                    "cwe_id": f"CWE-{cwe_id}"
                }
            )
        )

    return docs


cwe_docs = ingest_cwe("cwec_v4.19.1.xml")


# ==============================
# MERGE ALL DOCUMENTS
# ==============================

all_docs = []
all_docs += mitre_docs
all_docs += atm_docs
all_docs += capec_docs
all_docs += cwe_docs


# ==============================
# SOURCE COUNT SUMMARY
# ==============================

print(Counter([d.meta["source"] for d in all_docs]))
# Out:
# Counter({'CWE': 969, 'CAPEC': 613, 'MITRE_MOBILE': 176, 'MITRE_ICS': 95, 'ATM': 77})

# %%
# ========== 6. LOAD & EMBED ALL DOCUMENTS (ISO + Annex + ECU + MITRE + ATM + CAPEC + CWE) ==========

import json, glob, os
from haystack import Document

# ------------------------------------------------------------------
# PATHS (adjust only if filenames change)
# ------------------------------------------------------------------
CLAUSE_PATH = "./clauses"          # clause-5.json, clause-6.json, ...
ANNEX_PATH  = "annex.json"         # Annex F
DATA_PATH   = "data1.json"          # ECU / system data

# ------------------------------------------------------------------
# LOAD ECU / SYSTEM DATA
# ------------------------------------------------------------------
with open(DATA_PATH, "r", encoding="utf-8") as f:
    ecu_data = json.load(f)

ecu_docs = []
for k, v in ecu_data.items():
    ecu_docs.append(
        Document(
            content=json.dumps(v, indent=2),
            meta={
                "source": "ECU",
                "title": k
            }
        )
    )

print(f"⚙️ Loaded {len(ecu_docs)} ECU documents")

# ------------------------------------------------------------------
# LOAD ISO 21434 CLAUSE JSONs
# ------------------------------------------------------------------
clause_files = sorted(glob.glob(os.path.join(CLAUSE_PATH, "clause-*.json")))
iso_docs = []

for file in clause_files:
    with open(file, "r", encoding="utf-8") as f:
        clause_content = json.load(f)

    clause_number = os.path.splitext(os.path.basename(file))[0].split("-")[1]

    iso_docs.append(
        Document(
            content=clause_content.get(
                "content",
                json.dumps(clause_content, indent=2)
            ),
            meta={
                "source": "ISO_21434",
                "clause": clause_number,
                "title": clause_content.get("title", f"Clause {clause_number}")
            }
        )
    )

print(f"📘 Loaded {len(iso_docs)} ISO 21434 clauses")

# ------------------------------------------------------------------
# LOAD ANNEX F
# ------------------------------------------------------------------
annex_docs = []

if os.path.exists(ANNEX_PATH):
    with open(ANNEX_PATH, "r", encoding="utf-8") as f:
        annex_json = json.load(f)

    content_parts = [
        f"Annex {annex_json.get('annex_id', '')}: {annex_json.get('annex_title', '')}"
    ]

    for section in annex_json.get("sections", []):
        content_parts.append(
            f"\n\n### {section.get('section_id')} — {section.get('section_title')}"
        )

        for c in section.get("content", []):
            content_parts.append(f"- {c}")

        for t in section.get("tables", []):
            content_parts.append(
                f"\nTable {t.get('table_id')}: {t.get('table_title')}"
            )
            cols = t.get("columns", [])
            rows = t.get("rows", [])

            if cols and rows:
                content_parts.append(" | ".join(cols))
                content_parts.append("-" * 40)
                for r in rows:
                    content_parts.append(
                        " | ".join(str(r.get(col, "")) for col in cols)
                    )

        for note in section.get("notes", []):
            content_parts.append(f"Note: {note}")

    annex_docs.append(
        Document(
            content="\n".join(content_parts),
            meta={
                "source": "ANNEX_F",
                "annex": annex_json.get("annex_id"),
                "title": annex_json.get("annex_title")
            }
        )
    )

    print(f"📗 Loaded Annex F")

else:
    print("⚠️ Annex F not found – skipping")

# ------------------------------------------------------------------
# MERGE ALL SOURCES
# (These lists MUST already exist from earlier cells)
# ------------------------------------------------------------------
# mitre_docs   -> MITRE ATT&CK (ICS + Mobile)
# atm_docs     -> Automotive Threat Matrix
# capec_docs   -> CAPEC
# cwe_docs     -> CWE

all_docs = []
all_docs += ecu_docs
all_docs += iso_docs
all_docs += annex_docs
all_docs += mitre_docs
all_docs += atm_docs
all_docs += capec_docs
all_docs += cwe_docs

print(f"📄 Total documents before embedding: {len(all_docs)}")

# ------------------------------------------------------------------
# EMBED + STORE (ONCE — CORRECT WAY)
# ------------------------------------------------------------------
result = doc_embedder.run(documents=all_docs)
embedded_docs = result["documents"]

document_store.write_documents(embedded_docs)

print(f"✅ {len(embedded_docs)} documents embedded and stored")

# ------------------------------------------------------------------
# SUMMARY BY SOURCE (VERY IMPORTANT CHECK)
# ------------------------------------------------------------------
from collections import Counter
summary = Counter(d.meta.get("source", "Unknown") for d in embedded_docs)
print("📊 Document distribution:")
for k, v in summary.items():
    print(f"  {k}: {v}")
# Out:
# ⚙️ Loaded 2 ECU documents
# 📘 Loaded 0 ISO 21434 clauses
# 📗 Loaded Annex F
# 📄 Total documents before embedding: 1933
# Batches:   0%|          | 0/61 [00:00<?, ?it/s]
# ✅ 1933 documents embedded and stored
# 📊 Document distribution:
#   ECU: 2
#   ANNEX_F: 1
#   MITRE_MOBILE: 176
#   MITRE_ICS: 95
#   ATM: 77
#   CAPEC: 613
#   CWE: 969

# %%
from haystack.dataclasses import Document
from haystack.document_stores.in_memory import InMemoryDocumentStore
def inspect_document_store(document_store, limit=5):
    docs = document_store.filter_documents()

    print(f"\nTotal documents in store: {len(docs)}\n")

    for i, doc in enumerate(docs[:limit], 1):
        print(f"--- Document {i} ---")
        print(f"ID      : {doc.id}")
        print(f"Content : {doc.content[:500]}...")
        print(f"Meta    : {doc.meta}\n")

# %%
docs = document_store.filter_documents()

print("Docs:", len(docs))
print("Embedding exists:", docs[0].embedding is not None)
# Out:
# Docs: 1936
# Embedding exists: True

# %%
from collections import Counter

docs = document_store.filter_documents()

Counter(d.meta.get("source") for d in docs)
inspect_document_store(document_store)
# Out:
# Total documents in store: 1936
#
# --- Document 1 ---
# ID      : b3840fa854592790e4c0179c46f448857ef2164b42a188d46a2eeadbb0b86d49
# Content : {
#   "name": "Vehicle Infotainment System",
#   "type": "Vehicle System",
#   "domain": "HMI",
#   "description": "In-vehicle infotainment platform providing media playback, navigation, smartphone connectivity, and user interface interaction with the vehicle.",
#   "interfaces": [
#     "CAN Bus",
#     "Bluetooth",
#     "WiFi",
#     "USB",
#     "Display Interface",
#     "Microphone",
#     "Speaker System"
#   ],
#   "hint": "Typical architecture includes head unit processor, operating system, connectivity modules, d...
# Meta    : {'source': 'Vehicle System', 'clause': None, 'annex': None, 'title': 'Untitled'}
#
# --- Document 2 ---
# ID      : fd66fe551362de8f0e2dfe6fdaf08099ba52148f9faa34ea9f31bf1597788f42
# Content : {
#   "name": "Vehicle Gateway ECU",
#   "type": "ECU",
#   "domain": "Vehicle Network",
#   "description": "Central communication controller responsible for routing and filtering messages between different in-vehicle networks.",
#   "interfaces": [
#     "CAN Bus",
#     "LIN Bus",
#     "Ethernet",
#     "Diagnostics Interface",
#     "Security Module"
#   ],
#   "hint": "Typical architecture includes network controllers, message routing logic, firewall or filtering modules, security gateway functionality, and diagno...
# Meta    : {'source': 'ECU', 'clause': None, 'annex': None, 'title': 'Untitled'}
#
# --- Document 3 ---
# ID      : 43bb205e6a8fe5037b569e3c4501baaf966269f6196919a81733e8750b91ab4b
# Content : Annex F — Guidelines for Impact Rating
#
#
# ### F.1 — General
#
# - This annex provides example criteria for impact rating (see 15.5) for damage scenarios involving safety, financial, operational, and privacy impacts.
# - Tables F.1 through F.4 provide example rating criteria for each impact category.
# - Scalability of damage (impact to multiple road users in a single scenario) is not included here but can be added in organization-specific rating criteria.
#
#
# ### F.2 — Impact Rating for Safety Damage
#
#
#
# T...
# Meta    : {'source': 'Annex', 'clause': None, 'annex': 'F', 'title': 'Guidelines for Impact Rating'}
#
# --- Document 4 ---
# ID      : 4c61ed8302fbdf55df0552430d5e782a56c8483dd0af3fe3105902d230e1b5e7
# Content : {
#   "name": "Vehicle Infotainment System",
#   "type": "Vehicle System",
#   "domain": "HMI",
#   "description": "In-vehicle infotainment platform providing media playback, navigation, smartphone connectivity, and user interface interaction with the vehicle.",
#   "interfaces": [
#     "CAN Bus",
#     "Bluetooth",
#     "WiFi",
#     "USB",
#     "Display Interface",
#     "Microphone",
#     "Speaker System"
#   ],
#   "hint": "Typical architecture includes head unit processor, operating system, connectivity modules, d...
# Meta    : {'source': 'ECU', 'title': 'infotainment'}
#
# --- Document 5 ---
# ID      : f46719710d3628e017c4c10faa963e16edaed72683a129a478910a2787dcc5d9
# Content : {
#   "name": "Vehicle Gateway ECU",
#   "type": "ECU",
#   "domain": "Vehicle Network",
#   "description": "Central communication controller responsible for routing and filtering messages between different in-vehicle networks.",
#   "interfaces": [
#     "CAN Bus",
#     "LIN Bus",
#     "Ethernet",
#     "Diagnostics Interface",
#     "Security Module"
#   ],
#   "hint": "Typical architecture includes network controllers, message routing logic, firewall or filtering modules, security gateway functionality, and diagno...
# Meta    : {'source': 'ECU', 'title': 'gateway_ecu'}

# %% [markdown]
# INPUT LLM API KEY

# %%
import os

# 🔐 Paste your key directly ONCE
os.environ["GOOGLE_API_KEY"] = "AIzaSyBGK3BpAHuI-hUF5_R1Pul-Fk7pTNNAchs"

print("GOOGLE_API_KEY set")
# Out:
# GOOGLE_API_KEY set

# %%
# ========== 4. LLM SETUP ==========

import os

if "GOOGLE_API_KEY" not in os.environ:
    raise EnvironmentError("❌ GOOGLE_API_KEY not set in environment")

generator = GoogleAIGeminiGenerator(
    model="gemini-2.5-flash-lite"
)

print("🤖 Gemini generator ready.")
# Out:
# 🤖 Gemini generator ready.

# %% [markdown]
# TEMPLATE/PROMPT BUILDER

# %%
template = """
You are an automotive cybersecurity analyst performing a Threat Analysis and Risk Assessment (TARA)
according to ISO/SAE 21434 Clause 15.

Your task is to generate a system architecture model and damage scenarios
for the requested automotive component or ECU.

Use cybersecurity knowledge retrieved from the context which may include:

- ISO 21434 clauses
- CWE weaknesses
- CAPEC attack patterns
- MITRE ATT&CK techniques
- Automotive Threat Matrix (ATM)

Use this knowledge to reason about:

- system assets
- architecture relationships
- cybersecurity threats
- damage scenarios

-------------------------------------------------

SYSTEM REQUEST:
{{question}}

CYBERSECURITY KNOWLEDGE CONTEXT:
{{documents}}

-------------------------------------------------

TASK

1. Identify the system architecture for the requested component or system.
2. Derive assets (subsystems or components).
3. Create architecture relationships between components.
4. Map possible cybersecurity damage scenarios using retrieved threat knowledge.
5. Ensure assets and threats are realistic and technically consistent.

The architecture must be structured as nodes and edges so it can be visualized.

STRICT OUTPUT FORMAT

Return ONLY valid JSON.

Do not include explanations.
Do not include comments.

Return JSON strictly in this format:

{
 "assets":{
   "_id":"",
   "user_id":"",
   "model_id":"",

   "template":{
      "nodes":[
         {
           "id":"",
           "type":"component",
           "parentId":"",
           "isAsset":true,
           "data":{
              "label":"",
              "description":""
           },
           "properties":[
              "Integrity",
              "Confidentiality",
              "Availability"
           ],
           "style":{
              "width":200,
              "height":80
           },
           "position":{
              "x":0,
              "y":0
           }
         }
      ],

      "edges":[
         {
           "id":"",
           "source":"",
           "target":"",
           "type":"smoothstep",
           "data":{
              "label":""
           }
         }
      ],

      "details":[
         {
           "nodeId":"",
           "name":"",
           "desc":"",
           "type":"",
           "props":[
             {
               "name":"",
               "id":""
             }
           ]
         }
      ]
   }
 },

 "damage_scenarios":{
   "_id":"",
   "model_id":"",
   "type":"damage",

   "derivation":[
      {
        "id":"",
        "nodeId":"",
        "task":"Threat Analysis",
        "name":"",
        "loss":"",
        "asset":"",
        "damage_scene":"",
        "isChecked":false
      }
   ],

   "details":[
      {
        "nodeId":"",
        "name":"",
        "desc":"",
        "type":"",
        "props":[
           {
             "name":"",
             "id":""
           }
        ]
      }
   ]
 }
}
-------------------------------------------------

CONSTRAINTS

- Identify at least 10 system components.
- Create architecture relationships between components.
- Each component must have a clear cybersecurity role.
- Damage scenarios must reference the corresponding nodeId.
- Damage scenarios must be derived using threat knowledge (CWE, MITRE, CAPEC, ATM).
- Ensure the architecture reflects realistic automotive system design.

Return JSON only.

Start the response with '{'.

---
"""
prompt_builder = PromptBuilder(
    template=template,
    required_variables=["documents", "question"]
)

print(" PromptBuilder initialized.")
# Out:
#  PromptBuilder initialized.

# %% [markdown]
# BUILD RAG PIPELINE

# %%
# ========== 5. PIPELINE BUILD ==========
from haystack import Pipeline

basic_rag_pipeline = Pipeline()
basic_rag_pipeline.add_component("text_embedder", text_embedder)
basic_rag_pipeline.add_component("retriever", retriever)
basic_rag_pipeline.add_component("prompt_builder", prompt_builder)
basic_rag_pipeline.add_component("llm", generator)

basic_rag_pipeline.connect("text_embedder.embedding", "retriever.query_embedding")
basic_rag_pipeline.connect("retriever", "prompt_builder.documents")
basic_rag_pipeline.connect("prompt_builder", "llm")

print("✅ RAG pipeline built and connected successfully.")
# Out:
# ✅ RAG pipeline built and connected successfully.

# %%
# %%writefile tara_backend.py
# ==============================================
# TARA BACKEND — STREAMLIT / PRODUCTION VERSION
# ISO + ECU + ANNEX + MITRE + ATM + CAPEC + CWE
# ==============================================

# ========== 1. IMPORTS ==========
import os
import json
import glob
from pathlib import Path

from haystack import Pipeline, Document
from haystack.document_stores.in_memory import InMemoryDocumentStore
from haystack.components.embedders import (
    SentenceTransformersDocumentEmbedder,
    SentenceTransformersTextEmbedder,
)
from haystack.components.retrievers.in_memory import InMemoryEmbeddingRetriever
from haystack.components.builders import PromptBuilder
from haystack_integrations.components.generators.google_ai import GoogleAIGeminiGenerator

print("✅ Imports complete.")

# ========== 2. DOCUMENT STORE & EMBEDDERS ==========
document_store = InMemoryDocumentStore()
print("🧠 Document store initialized.")

doc_embedder = SentenceTransformersDocumentEmbedder(
    model="sentence-transformers/all-MiniLM-L6-v2"
)
text_embedder = SentenceTransformersTextEmbedder(
    model="sentence-transformers/all-MiniLM-L6-v2"
)

doc_embedder.warm_up()
print("✅ Embedders ready.")

retriever = InMemoryEmbeddingRetriever(document_store)
print("🔍 Retriever initialized.")

# ========== 3. STRICT ISO PROMPT ==========

template = """
You are an automotive cybersecurity analyst performing a Threat Analysis and Risk Assessment (TARA)
according to ISO/SAE 21434 Clause 15.

Your task is to generate a system architecture model and damage scenarios
for the requested automotive component or ECU.

Use cybersecurity knowledge retrieved from the context which may include:

- ISO 21434 clauses
- CWE weaknesses
- CAPEC attack patterns
- MITRE ATT&CK techniques
- Automotive Threat Matrix (ATM)

Use this knowledge to reason about:

- system assets
- architecture relationships
- cybersecurity threats
- damage scenarios

-------------------------------------------------

SYSTEM REQUEST:
{{question}}

CYBERSECURITY KNOWLEDGE CONTEXT:
{{documents}}

-------------------------------------------------

TASK

1. Identify the system architecture for the requested component or system.
2. Derive assets (subsystems or components).
3. Create architecture relationships between components.
4. Map possible cybersecurity damage scenarios using retrieved threat knowledge.
5. Ensure assets and threats are realistic and technically consistent.

The architecture must be structured as nodes and edges so it can be visualized.

STRICT OUTPUT FORMAT

Return ONLY valid JSON.

Do not include explanations.
Do not include comments.

Return JSON strictly in this format:

{
 "assets":{
   "_id":"",
   "user_id":"",
   "model_id":"",
   "template":"{{question}}",
   "nodes":[
      {
        "id":"",
        "type":"component",
        "parentId":"",
        "isAsset":true,
        "data":{
           "label":"",
           "description":""
        },
        "properties":[
           "Integrity",
           "Confidentiality",
           "Availability"
        ],
        "style":{
           "width":200,
           "height":80
        },
        "position":{
           "x":0,
           "y":0
        },
        "dragging":false,
        "resizing":false,
        "selected":false
      }
   ],

   "edges":[
      {
        "id":"",
        "source":"",
        "target":"",
        "type":"smoothstep",
        "animated":false,
        "markerStart":"",
        "markerEnd":"",
        "style":{},
        "data":{
           "label":"",
           "offset":0,
           "t":0
        }
      }
   ],

   "details":[
      {
        "nodeId":"",
        "name":"",
        "desc":"",
        "type":"",
        "props":[
          {
            "name":"",
            "id":""
          }
        ]
      }
   ]
 },

 "damage_scenarios":{
    "_id":"",
    "model_id":"",
    "type":"damage",

    "derivation":[
      {
        "id":"",
        "nodeId":"",
        "task":"Threat Analysis",
        "name":"",
        "loss":"",
        "asset":"",
        "damage_scene":"",
        "isChecked":false
      }
    ],

    "details":[
      {
        "nodeId":"",
        "name":"",
        "desc":"",
        "type":"",
        "props":[
          {
            "name":"",
            "id":""
          }
        ]
      }
    ]
 }
}

-------------------------------------------------

CONSTRAINTS

- Identify at least 10 system components.
- Create architecture relationships between components.
- Each component must have a clear cybersecurity role.
- Damage scenarios must reference the corresponding nodeId.
- Damage scenarios must be derived using threat knowledge (CWE, MITRE, CAPEC, ATM).
- Ensure the architecture reflects realistic automotive system design.

Return JSON only.

Start the response with '{'.

---
"""

prompt_builder = PromptBuilder(
    template=template,
    required_variables=["documents", "question"]
)

print("🧾 PromptBuilder initialized (STRICT ISO MODE).")

# ========== 4. GEMINI ==========
if "GOOGLE_API_KEY" not in os.environ:
    raise EnvironmentError("❌ GOOGLE_API_KEY not set")

generator = GoogleAIGeminiGenerator(
    model="gemini-2.5-flash-lite"
)

print("Gemini initialized.")

# ========== 5. PIPELINE ==========
basic_rag_pipeline = Pipeline()

basic_rag_pipeline.add_component("text_embedder", text_embedder)
basic_rag_pipeline.add_component("retriever", retriever)
basic_rag_pipeline.add_component("prompt_builder", prompt_builder)
basic_rag_pipeline.add_component("llm", generator)

basic_rag_pipeline.connect("text_embedder.embedding", "retriever.query_embedding")
basic_rag_pipeline.connect("retriever", "prompt_builder.documents")
basic_rag_pipeline.connect("prompt_builder", "llm")

print("✅ RAG pipeline built.")

# ========== 6. LOAD DOCUMENTS ==========
CLAUSE_PATH = "./clauses"
ANNEX_PATH = "annex.json"
DATA_PATH = "data.json"

docs = []

# ---------- ECU ----------
with open(DATA_PATH, "r", encoding="utf-8") as f:
    ecu_data = json.load(f)

for name, data in ecu_data.items():
    docs.append(
        Document(
            content=json.dumps(data, indent=2),
            meta={"source": "ECU", "title": name}
        )
    )

print(f"⚙️ ECU docs loaded: {len(ecu_data)}")

# ---------- ISO CLAUSES ----------
for file in glob.glob(os.path.join(CLAUSE_PATH, "clause-*.json")):
    with open(file, "r", encoding="utf-8") as f:
        clause = json.load(f)

    clause_id = Path(file).stem
    docs.append(
        Document(
            content=clause.get("content", json.dumps(clause, indent=2)),
            meta={"source": "ISO_21434", "clause": clause_id}
        )
    )

print("📘 ISO clauses loaded.")

# ---------- ANNEX ----------
if os.path.exists(ANNEX_PATH):
    with open(ANNEX_PATH, "r", encoding="utf-8") as f:
        annex = json.load(f)

    docs.append(
        Document(
            content=json.dumps(annex, indent=2),
            meta={"source": "ANNEX_F"}
        )
    )
    print("📗 Annex F loaded.")

# ---------- HELPER: LOAD PREBUILT THREAT DOCS ----------
def load_docs(path, source):
    loaded = []
    if not os.path.exists(path):
        print(f"⚠️ Missing {path}")
        return loaded

    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)

    for d in data:
        loaded.append(
            Document(
                content=d["content"],
                meta={**d.get("meta", {}), "source": source}
            )
        )
    return loaded

# ---------- THREAT INTEL ----------
docs += load_docs("mitre_docs.json", "MITRE")
docs += load_docs("atm_docs.json", "ATM")
docs += load_docs("capec_docs.json", "CAPEC")
docs += load_docs("cwe_docs.json", "CWE")

print(f"📄 Total documents before embedding: {len(docs)}")

# ========== 7. EMBED & STORE (ONCE) ==========
embedded_docs = doc_embedder.run(documents=docs)["documents"]
document_store.write_documents(embedded_docs)

print(f" {len(embedded_docs)} documents embedded & stored.")

# ========== 8. EXPORT ==========
__all__ = ["basic_rag_pipeline"]
# Out:
# Overwriting tara_backend.py

# %%
user_query = " infotainment system"

# %%
result = basic_rag_pipeline.run(
    {
        "text_embedder": {"text": user_query},
        "prompt_builder": {
            "question": user_query
        }
    }
)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
response = result["llm"]["replies"][0]

print(response)
# Out:
# ```json
# {
#   "assets": {
#     "_id": "6b3d8f1a-0e7b-4c1a-8f0b-3d0a7e5c1d0f",
#     "user_id": "your_user_id",
#     "model_id": "infotainment_system_tara_model",
#     "template": "infotainment system",
#     "nodes": [
#       {
#         "id": "infotainment_head_unit",
#         "type": "component",
#         "parentId": "",
#         "isAsset": true,
#         "data": {
#           "label": "Infotainment Head Unit",
#           "description": "Central processing unit and display for infotainment functions."
#         },
#         "properties": [
#           "Integrity",
#           "Confidentiality",
#           "Availability"
#         ],
#         "style": {
#           "width": 200,
#           "height": 80
#         },
#         "position": {
#           "x": 100,
#           "y": 100
#         },
#         "dragging": false,
#         "resizing": false,
#         "selected": false
#       },
#       {
#         "id": "display_module",
#         "type": "component",
#         "parentId": "infotainment_head_unit",
#         "isAsset": true,
#         "data": {
#           "label": "Display Module",
#           "description": "Visual interface for user interaction."
#         },
#         "properties": [
#           "Integrity",
#           "Availability"
#         ],
#         "style": {
#           "width": 150,
#           "height": 60
#         },
#         "position": {
#           "x": 100,
#           "y": 250
#         },
#         "dragging": false,
#         "resizing": false,
#         "selected": false
#       },
#       {
#         "id": "audio_system",
#         "type": "component",
#         "parentId": "infotainment_head_unit",
#         "isAsset": true,
#         "data": {
#           "label": "Audio System",
#           "description": "Handles audio output for entertainment and notifications."
#         },
#         "properties": [
#           "Integrity",
#           "Availability"
#         ],
#         "style": {
#           "width": 150,
#           "height": 60
#         },
#         "position": {
#           "x": 350,
#           "y": 250
#         },
#         "dragging": false,
#         "resizing": false,
#         "selected": false
#       },
#       {
#         "id": "navigation_module",
#         "type": "component",
#         "parentId": "infotainment_head_unit",
#         "isAsset": true,
#         "data": {
#           "label": "Navigation Module",
#           "description": "Provides GPS and map functionalities."
#         },
#         "properties": [
#           "Integrity",
#           "Availability"
#         ],
#         "style": {
#           "width": 150,
#           "height": 60
#         },
#         "position": {
#           "x": 600,
#           "y": 100
#         },
#         "dragging": false,
#         "resizing": false,
#         "selected": false
#       },
#       {
#         "id": "connectivity_module",
#         "type": "component",
#         "parentId": "infotainment_head_unit",
#         "isAsset": true,
#         "data": {
#           "label": "Connectivity Module",
#           "description": "Handles Bluetooth, Wi-Fi, cellular, and other external connections."
#         },
#         "properties": [
#           "Integrity",
#           "Confidentiality",
#           "Availability"
#         ],
#         "style": {
#           "width": 180,
#           "height": 70
#         },
#         "position": {
#           "x": 100,
#           "y": 400
#         },
#         "dragging": false,
#         "resizing": false,
#         "selected": false
#       },
#       {
#         "id": "bluetooth_interface",
#         "type": "component",
#         "parentId": "connectivity_module",
#         "isAsset": true,
#         "data": {
#           "label": "Bluetooth Interface",
#           "description": "Interface for device pairing and data transfer."
#         },
#         "properties": [
#           "Integrity",
#           "Confidentiality"
#         ],
#         "style": {
#           "width": 140,
#           "height": 50
#         },
#         "position": {
#           "x": 100,
#           "y": 550
#         },
#         "dragging": false,
#         "resizing": false,
#         "selected": false
#       },
#       {
#         "id": "wi_fi_interface",
#         "type": "component",
#         "parentId": "connectivity_module",
#         "isAsset": true,
#         "data": {
#           "label": "Wi-Fi Interface",
#           "description": "Interface for wireless network connectivity."
#         },
#         "properties": [
#           "Integrity",
#           "Confidentiality"
#         ],
#         "style": {
#           "width": 140,
#           "height": 50
#         },
#         "position": {
#           "x": 300,
#           "y": 550
#         },
#         "dragging": false,
#         "resizing": false,
#         "selected": false
#       },
#       {
#         "id": "usb_interface",
#         "type": "component",
#         "parentId": "infotainment_head_unit",
#         "isAsset": true,
#         "data": {
#           "label": "USB Interface",
#           "description": "Port for media playback, device charging, and software updates."
#         },
#         "properties": [
#           "Integrity",
#           "Confidentiality",
#           "Availability"
#         ],
#         "style": {
#           "width": 140,
#           "height": 50
#         },
#         "position": {
#           "x": 350,
#           "y": 400
#         },
#         "dragging": false,
#         "resizing": false,
#         "selected": false
#       },
#       {
#         "id": "vehicle_bus_gateway",
#         "type": "component",
#         "parentId": "",
#         "isAsset": true,
#         "data": {
#           "label": "Vehicle Bus Gateway",
#           "description": "Interface between infotainment system and other vehicle ECUs (e.g., CAN, Ethernet)."
#         },
#         "properties": [
#           "Integrity",
#           "Availability"
#         ],
#         "style": {
#           "width": 180,
#           "height": 70
#         },
#         "position": {
#           "x": 600,
#           "y": 400
#         },
#         "dragging": false,
#         "resizing": false,
#         "selected": false
#       },
#       {
#         "id": "microphone_input",
#         "type": "component",
#         "parentId": "infotainment_head_unit",
#         "isAsset": true,
#         "data": {
#           "label": "Microphone Input",
#           "description": "For voice commands and hands-free communication."
#         },
#         "properties": [
#           "Confidentiality",
#           "Availability"
#         ],
#         "style": {
#           "width": 150,
#           "height": 60
#         },
#         "position": {
#           "x": 600,
#           "y": 250
#         },
#         "dragging": false,
#         "resizing": false,
#         "selected": false
#       },
#       {
#         "id": "app_store_backend",
#         "type": "component",
#         "parentId": "",
#         "isAsset": true,
#         "data": {
#           "label": "App Store Backend",
#           "description": "Remote server for application downloads and updates."
#         },
#         "properties": [
#           "Integrity",
#           "Confidentiality",
#           "Availability"
#         ],
#         "style": {
#           "width": 180,
#           "height": 70
#         },
#         "position": {
#           "x": 100,
#           "y": 700
#         },
#         "dragging": false,
#         "resizing": false,
#         "selected": false
#       },
#       {
#         "id": "remote_diagnostics_server",
#         "type": "component",
#         "parentId": "",
#         "isAsset": true,
#         "data": {
#           "label": "Remote Diagnostics Server",
#           "description": "Server for remote diagnostics and software updates."
#         },
#         "properties": [
#           "Integrity",
#           "Confidentiality",
#           "Availability"
#         ],
#         "style": {
#           "width": 200,
#           "height": 80
#         },
#         "position": {
#           "x": 350,
#           "y": 700
#         },
#         "dragging": false,
#         "resizing": false,
#         "selected": false
#       }
#     ],
#     "edges": [
#       {
#         "id": "edge_1",
#         "source": "infotainment_head_unit",
#         "target": "display_module",
#         "type": "smoothstep",
#         "animated": false,
#         "markerStart": "",
#         "markerEnd": "arrowclosed",
#         "style": {},
#         "data": {
#           "label": "controls",
#           "offset": 0,
#           "t": 0
#         }
#       },
#       {
#         "id": "edge_2",
#         "source": "infotainment_head_unit",
#         "target": "audio_system",
#         "type": "smoothstep",
#         "animated": false,
#         "markerStart": "",
#         "markerEnd": "arrowclosed",
#         "style": {},
#         "data": {
#           "label": "controls",
#           "offset": 0,
#           "t": 0
#         }
#       },
#       {
#         "id": "edge_3",
#         "source": "infotainment_head_unit",
#         "target": "navigation_module",
#         "type": "smoothstep",
#         "animated": false,
#         "markerStart": "",
#         "markerEnd": "arrowclosed",
#         "style": {},
#         "data": {
#           "label": "utilizes",
#           "offset": 0,
#           "t": 0
#         }
#       },
#       {
#         "id": "edge_4",
#         "source": "infotainment_head_unit",
#         "target": "connectivity_module",
#         "type": "smoothstep",
#         "animated": false,
#         "markerStart": "",
#         "markerEnd": "arrowclosed",
#         "style": {},
#         "data": {
#           "label": "integrates",
#           "offset": 0,
#           "t": 0
#         }
#       },
#       {
#         "id": "edge_5",
#         "source": "infotainment_head_unit",
#         "target": "usb_interface",
#         "type": "smoothstep",
#         "animated": false,
#         "markerStart": "",
#         "markerEnd": "arrowclosed",
#         "style": {},
#         "data": {
#           "label": "connects",
#           "offset": 0,
#           "t": 0
#         }
#       },
#       {
#         "id": "edge_6",
#         "source": "infotainment_head_unit",
#         "target": "microphone_input",
#         "type": "smoothstep",
#         "animated": false,
#         "markerStart": "",
#         "markerEnd": "arrowclosed",
#         "style": {},
#         "data": {
#           "label": "receives input from",
#           "offset": 0,
#           "t": 0
#         }
#       },
#       {
#         "id": "edge_7",
#         "source": "connectivity_module",
#         "target": "bluetooth_interface",
#         "type": "smoothstep",
#         "animated": false,
#         "markerStart": "",
#         "markerEnd": "arrowclosed",
#         "style": {},
#         "data": {
#           "label": "provides",
#           "offset": 0,
#           "t": 0
#         }
#       },
#       {
#         "id": "edge_8",
#         "source": "connectivity_module",
#         "target": "wi_fi_interface",
#         "type": "smoothstep",
#         "animated": false,
#         "markerStart": "",
#         "markerEnd": "arrowclosed",
#         "style": {},
#         "data": {
#           "label": "provides",
#           "offset": 0,
#           "t": 0
#         }
#       },
#       {
#         "id": "edge_9",
#         "source": "infotainment_head_unit",
#         "target": "vehicle_bus_gateway",
#         "type": "smoothstep",
#         "animated": false,
#         "markerStart": "",
#         "markerEnd": "arrowclosed",
#         "style": {},
#         "data": {
#           "label": "communicates with",
#           "offset": 0,
#           "t": 0
#         }
#       },
#       {
#         "id": "edge_10",
#         "source": "connectivity_module",
#         "target": "app_store_backend",
#         "type": "smoothstep",
#         "animated": false,
#         "markerStart": "",
#         "markerEnd": "arrowclosed",
#         "style": {},
#         "data": {
#           "label": "connects to",
#           "offset": 0,
#           "t": 0
#         }
#       },
#       {
#         "id": "edge_11",
#         "source": "connectivity_module",
#         "target": "remote_diagnostics_server",
#         "type": "smoothstep",
#         "animated": false,
#         "markerStart": "",
#         "markerEnd": "arrowclosed",
#         "style": {},
#         "data": {
#           "label": "connects to",
#           "offset": 0,
#           "t": 0
#         }
#       },
#       {
#         "id": "edge_12",
#         "source": "vehicle_bus_gateway",
#         "target": "infotainment_head_unit",
#         "type": "smoothstep",
#         "animated": false,
#         "markerStart": "",
#         "markerEnd": "arrowclosed",
#         "style": {},
#         "data": {
#           "label": "communicates with",
#           "offset": 0,
#           "t": 0
#         }
#       }
#     ],
#     "details": [
#       {
#         "nodeId": "infotainment_head_unit",
#         "name": "Infotainment Head Unit",
#         "desc": "Central processing unit and display for infotainment functions.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "Confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "display_module",
#         "name": "Display Module",
#         "desc": "Visual interface for user interaction.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "audio_system",
#         "name": "Audio System",
#         "desc": "Handles audio output for entertainment and notifications.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "navigation_module",
#         "name": "Navigation Module",
#         "desc": "Provides GPS and map functionalities.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "connectivity_module",
#         "name": "Connectivity Module",
#         "desc": "Handles Bluetooth, Wi-Fi, cellular, and other external connections.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "Confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "bluetooth_interface",
#         "name": "Bluetooth Interface",
#         "desc": "Interface for device pairing and data transfer.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "Confidentiality"
#           }
#         ]
#       },
#       {
#         "nodeId": "wi_fi_interface",
#         "name": "Wi-Fi Interface",
#         "desc": "Interface for wireless network connectivity.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "Confidentiality"
#           }
#         ]
#       },
#       {
#         "nodeId": "usb_interface",
#         "name": "USB Interface",
#         "desc": "Port for media playback, device charging, and software updates.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "Confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "vehicle_bus_gateway",
#         "name": "Vehicle Bus Gateway",
#         "desc": "Interface between infotainment system and other vehicle ECUs (e.g., CAN, Ethernet).",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "microphone_input",
#         "name": "Microphone Input",
#         "desc": "For voice commands and hands-free communication.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Confidentiality",
#             "id": "Confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "app_store_backend",
#         "name": "App Store Backend",
#         "desc": "Remote server for application downloads and updates.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "Confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "remote_diagnostics_server",
#         "name": "Remote Diagnostics Server",
#         "desc": "Server for remote diagnostics and software updates.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "Confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       }
#     ]
#   },
#   "damage_scenarios": {
#     "_id": "a7f9c1e0-1d2b-4a0f-8e1c-7d9a6b2c0d1f",
#     "model_id": "infotainment_system_tara_model",
#     "type": "damage",
#     "derivation": [
#       {
#         "id": "ds_001",
#         "nodeId": "infotainment_head_unit",
#         "task": "Threat Analysis",
#         "name": "Unauthorized Access to Personal Data",
#         "loss": "Privacy Breach, Financial Loss",
#         "asset": "Infotainment Head Unit",
#         "damage_scene": "Attacker exploits a vulnerability (e.g., CWE-1083) to gain access to stored personal data (e.g., contacts, call logs, location history) on the head unit.",
#         "isChecked": false
#       },
#       {
#         "id": "ds_002",
#         "nodeId": "display_module",
#         "task": "Threat Analysis",
#         "name": "Display Tampering/Spoofing",
#         "loss": "Misdirection, Loss of Trust",
#         "asset": "Display Module",
#         "damage_scene": "Attacker manipulates the display output (MITRE: Manipulate I/O Image - relevant to data presentation) to show false information, such as incorrect navigation routes or misleading vehicle status.",
#         "isChecked": false
#       },
#       {
#         "id": "ds_003",
#         "nodeId": "audio_system",
#         "task": "Threat Analysis",
#         "name": "Audio System Disruption",
#         "loss": "Distraction, Annoyance, Safety Hazard",
#         "asset": "Audio System",
#         "damage_scene": "Attacker causes the audio system to play loud, disruptive noises, or to be completely inoperable (Availability loss), potentially distracting the driver or preventing important auditory alerts.",
#         "isChecked": false
#       },
#       {
#         "id": "ds_004",
#         "nodeId": "navigation_module",
#         "task": "Threat Analysis",
#         "name": "Navigation System Manipulation",
#         "loss": "Misdirection, Safety Hazard",
#         "asset": "Navigation Module",
#         "damage_scene": "Attacker corrupts navigation data (CAPEC-548) or modifies GPS signals to lead the driver to incorrect or dangerous locations.",
#         "isChecked": false
#       },
#       {
#         "id": "ds_005",
#         "nodeId": "connectivity_module",
#         "task": "Threat Analysis",
#         "name": "Unauthorized Remote Access",
#         "loss": "Data Theft, System Compromise, Control of Vehicle Functions",
#         "asset": "Connectivity Module",
#         "damage_scene": "Attacker exploits vulnerabilities in the connectivity module (e.g., Bluetooth or Wi-Fi) to gain unauthorized access to the infotainment system and potentially other vehicle networks (ATM: Gather Target Information – from Other).",
#         "isChecked": false
#       },
#       {
#         "id": "ds_006",
#         "nodeId": "bluetooth_interface",
#         "task": "Threat Analysis",
#         "name": "Bluetooth Eavesdropping or Hijacking",
#         "loss": "Privacy Breach, Data Theft",
#         "asset": "Bluetooth Interface",
#         "damage_scene": "Attacker performs Bluetooth eavesdropping or takes over an active Bluetooth session to intercept communications or gain unauthorized access to connected devices (e.g., a paired smartphone).",
#         "isChecked": false
#       },
#       {
#         "id": "ds_007",
#         "nodeId": "wi_fi_interface",
#         "task": "Threat Analysis",
#         "name": "Wi-Fi Network Exploitation",
#         "loss": "System Compromise, Data Theft",
#         "asset": "Wi-Fi Interface",
#         "damage_scene": "Attacker exploits vulnerabilities in the Wi-Fi interface to gain network access and compromise the infotainment system.",
#         "isChecked": false
#       },
#       {
#         "id": "ds_008",
#         "nodeId": "usb_interface",
#         "task": "Threat Analysis",
#         "name": "Malicious USB Device Injection",
#         "loss": "Malware Infection, Data Corruption, System Compromise",
#         "asset": "USB Interface",
#         "damage_scene": "Attacker inserts a malicious USB device to compromise the infotainment system, potentially exploiting vulnerabilities in how the system handles external storage (CWE-237).",
#         "isChecked": false
#       },
#       {
#         "id": "ds_009",
#         "nodeId": "vehicle_bus_gateway",
#         "task": "Threat Analysis",
#         "name": "Interception of Vehicle Data",
#         "loss": "Information Leakage, Manipulation of Vehicle Behavior",
#         "asset": "Vehicle Bus Gateway",
#         "damage_scene": "Attacker gains unauthorized access to the vehicle's internal network via the gateway to access telemetry data (ATM: Access vehicle telemetry) or send malicious commands.",
#         "isChecked": false
#       },
#       {
#         "id": "ds_010",
#         "nodeId": "microphone_input",
#         "task": "Threat Analysis",
#         "name": "Unauthorized Voice Data Capture",
#         "loss": "Privacy Breach",
#         "asset": "Microphone Input",
#         "damage_scene": "Attacker gains unauthorized control over the microphone to eavesdrop on conversations within the vehicle.",
#         "isChecked": false
#       },
#       {
#         "id": "ds_011",
#         "nodeId": "app_store_backend",
#         "task": "Threat Analysis",
#         "name": "Compromise of Application Integrity",
#         "loss": "Malware Infection, System Compromise",
#         "asset": "App Store Backend",
#         "damage_scene": "Attacker compromises the app store backend to distribute malicious applications that can then be installed on the infotainment system.",
#         "isChecked": false
#       },
#       {
#         "id": "ds_012",
#         "nodeId": "remote_diagnostics_server",
#         "task": "Threat Analysis",
#         "name": "Compromised Remote Update",
#         "loss": "System Compromise, Malware Infection",
#         "asset": "Remote Diagnostics Server",
#         "damage_scene": "Attacker compromises the remote diagnostics server to push malicious software updates to the infotainment system.",
#         "isChecked": false
#       },
#       {
#         "id": "ds_013",
#         "nodeId": "infotainment_head_unit",
#         "task": "Threat Analysis",
#         "name": "Cleartext Storage of Sensitive Information",
#         "loss": "Privacy Breach, Identity Theft",
#         "asset": "Infotainment Head Unit",
#         "damage_scene": "Attacker exploits vulnerabilities related to cleartext storage (CWE-312, CWE-317) to access sensitive information like login credentials or personally identifiable information stored on the head unit.",
#         "isChecked": false
#       },
#       {
#         "id": "ds_014",
#         "nodeId": "infotainment_head_unit",
#         "task": "Threat Analysis",
#         "name": "Screen Capture",
#         "loss": "Privacy Breach, Information Leakage",
#         "asset": "Infotainment Head Unit",
#         "damage_scene": "Attacker gains control of the infotainment system and performs screen capture (MITRE Technique: Screen Capture) to steal sensitive information displayed on the screen.",
#         "isChecked": false
#       }
#     ],
#     "details": [
#       {
#         "nodeId": "infotainment_head_unit",
#         "name": "Infotainment Head Unit",
#         "desc": "Central processing unit and display for infotainment functions.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "Confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "display_module",
#         "name": "Display Module",
#         "desc": "Visual interface for user interaction.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "audio_system",
#         "name": "Audio System",
#         "desc": "Handles audio output for entertainment and notifications.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "navigation_module",
#         "name": "Navigation Module",
#         "desc": "Provides GPS and map functionalities.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "connectivity_module",
#         "name": "Connectivity Module",
#         "desc": "Handles Bluetooth, Wi-Fi, cellular, and other external connections.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "Confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "bluetooth_interface",
#         "name": "Bluetooth Interface",
#         "desc": "Interface for device pairing and data transfer.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "Confidentiality"
#           }
#         ]
#       },
#       {
#         "nodeId": "wi_fi_interface",
#         "name": "Wi-Fi Interface",
#         "desc": "Interface for wireless network connectivity.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "Confidentiality"
#           }
#         ]
#       },
#       {
#         "nodeId": "usb_interface",
#         "name": "USB Interface",
#         "desc": "Port for media playback, device charging, and software updates.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "Confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "vehicle_bus_gateway",
#         "name": "Vehicle Bus Gateway",
#         "desc": "Interface between infotainment system and other vehicle ECUs (e.g., CAN, Ethernet).",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "microphone_input",
#         "name": "Microphone Input",
#         "desc": "For voice commands and hands-free communication.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Confidentiality",
#             "id": "Confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "app_store_backend",
#         "name": "App Store Backend",
#         "desc": "Remote server for application downloads and updates.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "Confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "remote_diagnostics_server",
#         "name": "Remote Diagnostics Server",
#         "desc": "Server for remote diagnostics and software updates.",
#         "type": "component",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "Integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "Confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "Availability"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
