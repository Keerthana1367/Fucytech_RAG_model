# %% [markdown]
# DEPENDENCIES INSTALLATION

# %%
# %%bash
# apt-get install -y libpango-1.0-0 libcairo2
# pip install -q haystack-ai
# pip install -q "datasets>=2.6.1"
# pip install -q "sentence-transformers>=2.2.0"
# pip install -q google-generativeai
# pip install -q google-ai-haystack
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# libcairo2 is already the newest version (1.16.0-5ubuntu2).
# libcairo2 set to manually installed.
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libpango-1.0-0 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 680.2/680.2 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.1/201.1 kB 14.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 3.7 MB/s eta 0:00:00

# %%
# !pip install -q streamlit==1.37 streamlit-colab
# !pip install -q reportlab
# !pip install -q weasyprint
# !pip install -q markdown2
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 45.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 51.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 36.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.9/82.9 kB 5.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.26.0 requires tenacity<10.0.0,>=9.0.0, but you have tenacity 8.5.0 which is incompatible.
# google-adk 1.26.0 requires watchdog<7.0.0,>=6.0.0, but you have watchdog 4.0.2 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 22.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.8/319.8 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 38.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.4/829.4 kB 34.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 1.6 MB/s eta 0:00:00

# %% [markdown]
# LIBRARY IMPORTS

# %%
# ========== 1. IMPORTS ==========
import os, json
from getpass import getpass
from haystack import Pipeline, Document
from haystack.document_stores.in_memory import InMemoryDocumentStore
from haystack.components.embedders import SentenceTransformersDocumentEmbedder, SentenceTransformersTextEmbedder
from haystack.components.retrievers.in_memory import InMemoryEmbeddingRetriever
from haystack.components.builders import PromptBuilder
from haystack_integrations.components.generators.google_ai import GoogleAIGeminiGenerator

print("✅ Imports complete.")
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)
# ✅ Imports complete.

# %% [markdown]
# SETUP EMBEDDER AND RETRIEVER

# %%
# ========== 2. COMPONENT SETUP ==========

document_store = InMemoryDocumentStore()
print("🧠 InMemoryDocumentStore initialized.")

doc_embedder = SentenceTransformersDocumentEmbedder(model="sentence-transformers/all-MiniLM-L6-v2")
text_embedder = SentenceTransformersTextEmbedder(model="sentence-transformers/all-MiniLM-L6-v2")

doc_embedder.warm_up()
print("✅ Document and Text embedders initialized and warmed up.")

# retriever = InMemoryEmbeddingRetriever(document_store)
retriever = InMemoryEmbeddingRetriever(document_store=document_store,top_k=40)
print("🔍 Retriever created and connected to document store.")
# Out:
# 🧠 InMemoryDocumentStore initialized.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ✅ Document and Text embedders initialized and warmed up.
# 🔍 Retriever created and connected to document store.

# %% [markdown]
# Data Ingestion(cybersecurity standards + threat framework)

# %%
# ==============================
# DATA INGESTION PIPELINE
# ==============================

import json
import xml.etree.ElementTree as ET
from lxml import etree
from haystack import Document
from collections import Counter


# ==============================
# MITRE ATT&CK (Mobile + ICS)
# ==============================

def ingest_mitre(path, source):
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)

    docs = []
    for obj in data.get("objects", []):
        if obj.get("type") == "attack-pattern":
            name = obj.get("name", "")
            desc = obj.get("description", "")

            if not desc:
                continue

            docs.append(
                Document(
                    content=f"MITRE Technique: {name}\nDescription: {desc}",
                    meta={
                        "source": source,
                        "stix_id": obj.get("id")
                    }
                )
            )
    return docs


mitre_docs = []
mitre_docs += ingest_mitre("mobile-attack (1).json", "MITRE_MOBILE")
mitre_docs += ingest_mitre("ics-attack (1).json", "MITRE_ICS")


# ==============================
# ATM
# ==============================

def ingest_atm(path):
    with open(path, "r", encoding="utf-8") as f:
        data = json.load(f)

    docs = []
    for obj in data.get("objects", []):
        if obj.get("type") == "attack-pattern":
            name = obj.get("name", "")
            desc = obj.get("description", "")

            if not desc:
                continue

            docs.append(
                Document(
                    content=f"ATM Technique: {name}\nDescription: {desc}",
                    meta={
                        "source": "ATM",
                        "stix_id": obj.get("id")
                    }
                )
            )
    return docs


atm_docs = ingest_atm("latest atm.json")


# ==============================
# CAPEC
# ==============================

def ingest_capec(xml_path):
    tree = ET.parse(xml_path)
    root = tree.getroot()

    ns = {"capec": "http://capec.mitre.org/capec-3"}
    docs = []

    for ap in root.findall(".//capec:Attack_Pattern", ns):
        capec_id = ap.get("ID")
        name = ap.findtext("capec:Name", default="", namespaces=ns)
        desc = ap.findtext("capec:Description", default="", namespaces=ns)

        if not desc:
            continue

        docs.append(
            Document(
                content=f"CAPEC-{capec_id}: {name}\nDescription: {desc}",
                meta={
                    "source": "CAPEC",
                    "capec_id": capec_id
                }
            )
        )
    return docs


capec_docs = ingest_capec("capec_v3.9.xml")


# ==============================
# CWE
# ==============================

def ingest_cwe(xml_path):
    parser = etree.XMLParser(recover=True, huge_tree=True)
    tree = etree.parse(xml_path, parser)
    root = tree.getroot()

    ns = {"cwe": "http://cwe.mitre.org/cwe-7"}
    docs = []

    for w in root.findall(".//cwe:Weakness", namespaces=ns):
        cwe_id = w.get("ID")
        name = w.get("Name")

        desc_elem = w.find("cwe:Description", namespaces=ns)
        desc = desc_elem.text if desc_elem is not None else ""

        if not desc:
            continue

        docs.append(
            Document(
                content=f"CWE-{cwe_id}: {name}\nDescription: {desc}",
                meta={
                    "source": "CWE",
                    "cwe_id": f"CWE-{cwe_id}"
                }
            )
        )

    return docs


cwe_docs = ingest_cwe("cwec_v4.19.1.xml")


# ==============================
# MERGE ALL DOCUMENTS
# ==============================

all_docs = []
all_docs += mitre_docs
all_docs += atm_docs
all_docs += capec_docs
all_docs += cwe_docs


# ==============================
# SOURCE COUNT SUMMARY
# ==============================

print(Counter([d.meta["source"] for d in all_docs]))
# Out:
# Counter({'CWE': 969, 'CAPEC': 613, 'MITRE_MOBILE': 176, 'MITRE_ICS': 95, 'ATM': 77})

# %%
# ========== 6. LOAD & EMBED ALL DOCUMENTS (ISO + Annex + ECU + MITRE + ATM + CAPEC + CWE) ==========

import json, glob, os
from haystack import Document

# ------------------------------------------------------------------
# PATHS (adjust only if filenames change)
# ------------------------------------------------------------------
CLAUSE_PATH = "./clauses"          # clause-5.json, clause-6.json, ...
ANNEX_PATH  = "annex.json"         # Annex F
DATA_PATH   = "data1.json"          # ECU / system data

# ------------------------------------------------------------------
# LOAD ECU / SYSTEM DATA
# ------------------------------------------------------------------
with open(DATA_PATH, "r", encoding="utf-8") as f:
    ecu_data = json.load(f)

ecu_docs = []
for k, v in ecu_data.items():
    ecu_docs.append(
        Document(
            content=json.dumps(v, indent=2),
            meta={
                "source": "ECU",
                "title": k
            }
        )
    )

print(f"⚙️ Loaded {len(ecu_docs)} ECU documents")

# ------------------------------------------------------------------
# LOAD ISO 21434 CLAUSE JSONs
# ------------------------------------------------------------------
clause_files = sorted(glob.glob(os.path.join(CLAUSE_PATH, "clause-*.json")))
iso_docs = []

for file in clause_files:
    with open(file, "r", encoding="utf-8") as f:
        clause_content = json.load(f)

    clause_number = os.path.splitext(os.path.basename(file))[0].split("-")[1]

    iso_docs.append(
        Document(
            content=clause_content.get(
                "content",
                json.dumps(clause_content, indent=2)
            ),
            meta={
                "source": "ISO_21434",
                "clause": clause_number,
                "title": clause_content.get("title", f"Clause {clause_number}")
            }
        )
    )

print(f" Loaded {len(iso_docs)} ISO 21434 clauses")

# ------------------------------------------------------------------
# LOAD ANNEX F
# ------------------------------------------------------------------
annex_docs = []

if os.path.exists(ANNEX_PATH):
    with open(ANNEX_PATH, "r", encoding="utf-8") as f:
        annex_json = json.load(f)

    content_parts = [
        f"Annex {annex_json.get('annex_id', '')}: {annex_json.get('annex_title', '')}"
    ]

    for section in annex_json.get("sections", []):
        content_parts.append(
            f"\n\n### {section.get('section_id')} — {section.get('section_title')}"
        )

        for c in section.get("content", []):
            content_parts.append(f"- {c}")

        for t in section.get("tables", []):
            content_parts.append(
                f"\nTable {t.get('table_id')}: {t.get('table_title')}"
            )
            cols = t.get("columns", [])
            rows = t.get("rows", [])

            if cols and rows:
                content_parts.append(" | ".join(cols))
                content_parts.append("-" * 40)
                for r in rows:
                    content_parts.append(
                        " | ".join(str(r.get(col, "")) for col in cols)
                    )

        for note in section.get("notes", []):
            content_parts.append(f"Note: {note}")

    annex_docs.append(
        Document(
            content="\n".join(content_parts),
            meta={
                "source": "ANNEX_F",
                "annex": annex_json.get("annex_id"),
                "title": annex_json.get("annex_title")
            }
        )
    )

    print(f"Loaded Annex F")

else:
    print(" Annex F not found – skipping")

# ------------------------------------------------------------------
# MERGE ALL SOURCES
# (These lists MUST already exist from earlier cells)
# ------------------------------------------------------------------
# mitre_docs   -> MITRE ATT&CK (ICS + Mobile)
# atm_docs     -> Automotive Threat Matrix
# capec_docs   -> CAPEC
# cwe_docs     -> CWE

all_docs = []
all_docs += ecu_docs
all_docs += iso_docs
all_docs += annex_docs
all_docs += mitre_docs
all_docs += atm_docs
all_docs += capec_docs
all_docs += cwe_docs

print(f" Total documents before embedding: {len(all_docs)}")

# ------------------------------------------------------------------
# EMBED + STORE (ONCE — CORRECT WAY)
# ------------------------------------------------------------------
result = doc_embedder.run(documents=all_docs)
embedded_docs = result["documents"]

document_store.write_documents(embedded_docs)

print(f" {len(embedded_docs)} documents embedded and stored")

# ------------------------------------------------------------------
# SUMMARY BY SOURCE (VERY IMPORTANT CHECK)
# ------------------------------------------------------------------
from collections import Counter
summary = Counter(d.meta.get("source", "Unknown") for d in embedded_docs)
print(" Document distribution:")
for k, v in summary.items():
    print(f"  {k}: {v}")
# Out:
# ⚙️ Loaded 2 ECU documents
#  Loaded 0 ISO 21434 clauses
# Loaded Annex F
#  Total documents before embedding: 1933
# Batches:   0%|          | 0/61 [00:00<?, ?it/s]
#  1933 documents embedded and stored
#  Document distribution:
#   ECU: 2
#   ANNEX_F: 1
#   MITRE_MOBILE: 176
#   MITRE_ICS: 95
#   ATM: 77
#   CAPEC: 613
#   CWE: 969

# %%
from haystack.dataclasses import Document
from haystack.document_stores.in_memory import InMemoryDocumentStore
def inspect_document_store(document_store, limit=5):
    docs = document_store.filter_documents()

    print(f"\nTotal documents in store: {len(docs)}\n")

    for i, doc in enumerate(docs[:limit], 1):
        print(f"--- Document {i} ---")
        print(f"ID      : {doc.id}")
        print(f"Content : {doc.content[:500]}...")
        print(f"Meta    : {doc.meta}\n")

# %%
docs = document_store.filter_documents()

print("Docs:", len(docs))
print("Embedding exists:", docs[0].embedding is not None)
# Out:
# Docs: 1933
# Embedding exists: True

# %%
from collections import Counter

docs = document_store.filter_documents()

Counter(d.meta.get("source") for d in docs)
inspect_document_store(document_store)
# Out:
# Total documents in store: 1933
#
# --- Document 1 ---
# ID      : 4c61ed8302fbdf55df0552430d5e782a56c8483dd0af3fe3105902d230e1b5e7
# Content : {
#   "name": "Vehicle Infotainment System",
#   "type": "Vehicle System",
#   "domain": "HMI",
#   "description": "In-vehicle infotainment platform providing media playback, navigation, smartphone connectivity, and user interface interaction with the vehicle.",
#   "interfaces": [
#     "CAN Bus",
#     "Bluetooth",
#     "WiFi",
#     "USB",
#     "Display Interface",
#     "Microphone",
#     "Speaker System"
#   ],
#   "hint": "Typical architecture includes head unit processor, operating system, connectivity modules, d...
# Meta    : {'source': 'ECU', 'title': 'infotainment'}
#
# --- Document 2 ---
# ID      : f46719710d3628e017c4c10faa963e16edaed72683a129a478910a2787dcc5d9
# Content : {
#   "name": "Vehicle Gateway ECU",
#   "type": "ECU",
#   "domain": "Vehicle Network",
#   "description": "Central communication controller responsible for routing and filtering messages between different in-vehicle networks.",
#   "interfaces": [
#     "CAN Bus",
#     "LIN Bus",
#     "Ethernet",
#     "Diagnostics Interface",
#     "Security Module"
#   ],
#   "hint": "Typical architecture includes network controllers, message routing logic, firewall or filtering modules, security gateway functionality, and diagno...
# Meta    : {'source': 'ECU', 'title': 'gateway_ecu'}
#
# --- Document 3 ---
# ID      : 2ee39ad7ccf26139aa81db7da3bb8289d778ed9fa8e61ae86eacdd2b6ca87048
# Content : Annex F: Guidelines for Impact Rating
#
#
# ### F.1 — General
# - This annex provides example criteria for impact rating (see 15.5) for damage scenarios involving safety, financial, operational, and privacy impacts.
# - Tables F.1 through F.4 provide example rating criteria for each impact category.
# - Scalability of damage (impact to multiple road users in a single scenario) is not included here but can be added in organization-specific rating criteria.
#
#
# ### F.2 — Impact Rating for Safety Damage
#
# Table...
# Meta    : {'source': 'ANNEX_F', 'annex': 'F', 'title': 'Guidelines for Impact Rating'}
#
# --- Document 4 ---
# ID      : fa5cf680be5ddc019b275e6116193a4230b82c6ad52de15630ce03e028984eeb
# Content : MITRE Technique: Scheduled Task/Job
# Description: Adversaries may abuse task scheduling functionality to facilitate initial or recurring execution of malicious code. On Android and iOS, APIs and libraries exist to facilitate scheduling tasks to execute at a specified date, time, or interval.
#
# On Android, the `WorkManager` API allows asynchronous tasks to be scheduled with the system. `WorkManager` was introduced to unify task scheduling on Android, using `JobScheduler`, `GcmNetworkManager`, and `...
# Meta    : {'source': 'MITRE_MOBILE', 'stix_id': 'attack-pattern--00290ac5-551e-44aa-bbd8-c4b913488a6d'}
#
# --- Document 5 ---
# ID      : c966ca5b44f1352a70166ce16fc450f27ec56dd596c6dea6b2b4cb54ba04251f
# Content : MITRE Technique: Code Injection
# Description: Adversaries may use code injection attacks to implant arbitrary code into the address space of a running application. Code is then executed or interpreted by that application. Adversaries utilizing this technique may exploit capabilities to load code in at runtime through dynamic libraries.
#
# With root access, `ptrace` can be used to target specific applications and load shared libraries into its process memory.(Citation: Shunix Code Injection Mar 2016...
# Meta    : {'source': 'MITRE_MOBILE', 'stix_id': 'attack-pattern--039bc59c-ecc7-4997-b2b4-4ab728bd91aa'}

# %% [markdown]
# INPUT LLM API KEY

# %%
import os

# 🔐 Paste your key directly ONCE
os.environ["GOOGLE_API_KEY"] = "AIzaSyBfPWB7NlT4HORwB-vDoudBN83jYmdR3sg"

print("GOOGLE_API_KEY set")
# Out:
# GOOGLE_API_KEY set

# %%
# ========== 4. LLM SETUP ==========

import os

if "GOOGLE_API_KEY" not in os.environ:
    raise EnvironmentError("❌ GOOGLE_API_KEY not set in environment")

generator = GoogleAIGeminiGenerator(
    model="gemini-2.5-flash-lite"
)

print("🤖 Gemini generator ready.")
# Out:
# 🤖 Gemini generator ready.

# %% [markdown]
# TEMPLATE/PROMPT BUILDER

# %%
template = """
You are an automotive cybersecurity analyst performing a Threat Analysis and Risk Assessment (TARA)
according to ISO/SAE 21434 Clause 15.

Your task is to generate a system architecture model and damage scenarios
for the requested automotive component or ECU.

Use cybersecurity knowledge retrieved from the context which may include:

- ISO 21434 clauses
- CWE weaknesses
- CAPEC attack patterns
- MITRE ATT&CK techniques
- Automotive Threat Matrix (ATM)

Use this knowledge to reason about:

- system assets
- architecture relationships
- cybersecurity threats
- damage scenarios

-------------------------------------------------

SYSTEM REQUEST:
{{question}}

CYBERSECURITY KNOWLEDGE CONTEXT:
{{documents}}

-------------------------------------------------

TASK

1. Identify the system architecture for the requested component or system.
2. Derive assets (subsystems or components).
3. Create architecture relationships between components.
4. Map possible cybersecurity damage scenarios using retrieved threat knowledge.
5. Ensure assets and threats are realistic and technically consistent.

The architecture must be structured as nodes and edges so it can be visualized.

STRICT OUTPUT FORMAT

Return ONLY valid JSON.

Do not include explanations.
Do not include comments.

Return JSON strictly in this format:

{
 "assets":{
   "_id":"",
   "user_id":"",
   "model_id":"",

   "template":{
      "nodes":[
         {
           "id":"",
           "type":"component",
           "parentId":"",
           "isAsset":true,
           "data":{
              "label":"",
              "description":""
           },
           "properties":[
              "Integrity",
              "Confidentiality",
              "Availability"
           ],
           "style":{
              "width":200,
              "height":80
           },
           "position":{
              "x":0,
              "y":0
           }
         }
      ],

      "edges":[
         {
           "id":"",
           "source":"",
           "target":"",
           "type":"smoothstep",
           "data":{
              "label":""
           }
         }
      ],

      "details":[
         {
           "nodeId":"",
           "name":"",
           "desc":"",
           "type":"",
           "props":[
             {
               "name":"",
               "id":""
             }
           ]
         }
      ]
   }
 },

 "damage_scenarios":{
   "_id":"",
   "model_id":"",
   "type":"damage",

   "derivation":[
      {
        "id":"",
        "nodeId":"",
        "task":"Threat Analysis",
        "name":"",
        "loss":"",
        "asset":"",
        "damage_scene":"",
        "isChecked":false
      }
   ],

   "details":[
      {
        "nodeId":"",
        "name":"",
        "desc":"",
        "type":"",
        "props":[
           {
             "name":"",
             "id":""
           }
        ]
      }
   ]
 }
}
-------------------------------------------------

CONSTRAINTS

- Identify at least 10 system components.
- Create architecture relationships between components.
- Each component must have a clear cybersecurity role.
- Damage scenarios must reference the corresponding nodeId.
- Damage scenarios must be derived using threat knowledge (CWE, MITRE, CAPEC, ATM).
- Ensure the architecture reflects realistic automotive system design.

Return JSON only.

Start the response with '{'.

---
"""
prompt_builder = PromptBuilder(
    template=template,
    required_variables=["documents", "question"]
)

print(" PromptBuilder initialized.")
# Out:
#  PromptBuilder initialized.

# %% [markdown]
# BUILD RAG PIPELINE

# %%
# ========== 5. PIPELINE BUILD ==========
from haystack import Pipeline

basic_rag_pipeline = Pipeline()
basic_rag_pipeline.add_component("text_embedder", text_embedder)
basic_rag_pipeline.add_component("retriever", retriever)
basic_rag_pipeline.add_component("prompt_builder", prompt_builder)
basic_rag_pipeline.add_component("llm", generator)

basic_rag_pipeline.connect("text_embedder.embedding", "retriever.query_embedding")
basic_rag_pipeline.connect("retriever", "prompt_builder.documents")
basic_rag_pipeline.connect("prompt_builder", "llm")

print("✅ RAG pipeline built and connected successfully.")
# Out:
# ✅ RAG pipeline built and connected successfully.

# %% [markdown]
# Results

# %%
user_query = " infotainment system"

# %%
result = basic_rag_pipeline.run(
    {
        "text_embedder": {"text": user_query},
        "prompt_builder": {"question": user_query}
    },
    include_outputs_from=["retriever"]
)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ##Relevant documents retrived from threat frameworks and cyber rules

# %%
docs = result["retriever"]["documents"]

print("Documents retrieved:", len(docs))

for i, doc in enumerate(docs):
    print(f"\nDocument {i+1}")
    print(doc.content[:400])
# Out:
# Documents retrieved: 40
#
# Document 1
# {
#   "name": "Vehicle Infotainment System",
#   "type": "Vehicle System",
#   "domain": "HMI",
#   "description": "In-vehicle infotainment platform providing media playback, navigation, smartphone connectivity, and user interface interaction with the vehicle.",
#   "interfaces": [
#     "CAN Bus",
#     "Bluetooth",
#     "WiFi",
#     "USB",
#     "Display Interface",
#     "Microphone",
#     "Speaker System"
#   ],
#   "
#
# Document 2
# ATM Technique: Gather Target Information – from Vehicle
# Description: The adversary gathers information by targeting a vehicle’s hardware and/or communication environment. Hardware includes physical components, such as Electronic Control Units (ECUs), sensors, FPGAs, microcontrollers, or SoCs. The communication environment involves any physical communication and wireless communication involving the
#
# Document 3
# CWE-1083: Data Access from Outside Expected Data Manager Component
# Description: The product is intended to manage data access through a particular data manager component such as a relational or non-SQL database, but it contains code that performs data access operations without using that component.
#
# Document 4
# CWE-1057: Data Access Operations Outside of Expected Data Manager Component
# Description: The product uses a dedicated, central data manager component as required by design, but it contains code that performs data-access operations that do not use this data manager.
#
# Document 5
# ATM Technique: Access vehicle telemetry
# Description:
# <p>Adversaries may try to collect vehicle telemetry, including propulsion system status (e.g., hard acceleration or braking), whether vehicle enclosures are locked / unlocked, etc.</p></div>
# </div>
# <div class="cell aside" data-type="aside">
#
#
# Document 6
# MITRE Technique: Screen Capture
# Description: Adversaries may attempt to perform screen capture of devices in the control system environment. Screenshots may be taken of workstations, HMIs, or other devices that display environment-relevant process, device, reporting, alarm, or related data. These device displays may reveal information regarding the ICS process, layout, control, and related schemat
#
# Document 7
# CWE-317: Cleartext Storage of Sensitive Information in GUI
# Description: The product stores sensitive information in cleartext within the GUI.
#
# Document 8
# ATM Technique: Gather Target Information – from Other
# Description: <p>The adversary gathers information by directly targeting sources that do not involve the vehicle and its services. Targeting organizations are included, such OEMs, suppliers, service providers, and dealerships. This may involve physically breaching an organization’s premises, infiltrating networks, or exploiting personnel with pr
#
# Document 9
# CWE-225: DEPRECATED: General Information Management Problems
# Description: This weakness can be found at CWE-199.
#
# Document 10
# CWE-915: Improperly Controlled Modification of Dynamically-Determined Object Attributes
# Description: The product receives input from an upstream component that specifies multiple attributes, properties, or fields that are to be initialized or updated in an object, but it does not properly control which attributes can be modified.
#
# Document 11
# CWE-15: External Control of System or Configuration Setting
# Description: One or more system settings or configuration elements can be externally controlled by a user.
#
# Document 12
# CWE-1249: Application-Level Admin Tool with Inconsistent View of Underlying Operating System
# Description: The product provides an application for administrators to manage parts of the underlying operating system, but the application does not accurately identify all of the relevant entities or resources that exist in the OS; that is, the application's model of the OS's state is inconsistent with th
#
# Document 13
# CWE-610: Externally Controlled Reference to a Resource in Another Sphere
# Description: The product uses an externally controlled name or reference that resolves to a resource that is outside of the intended control sphere.
#
# Document 14
# CWE-1251: Mirrored Regions with Different Values
# Description: The product's architecture mirrors regions without ensuring that their contents always stay in sync.
#
# Document 15
# MITRE Technique: Automated Collection
# Description: Adversaries may automate collection of industrial environment information using tools or scripts. This automated collection may leverage native control protocols and tools available in the control systems environment. For example, the OPC protocol may be used to enumerate and gather information. Access to a system or interface with these native pr
#
# Document 16
# CWE-1059: Insufficient Technical Documentation
# Description: The product does not contain sufficient
#          technical or engineering documentation (whether on paper or
#          in electronic form) that contains descriptions of all the
#          relevant software/hardware elements of the product, such as
#          its usage, structure, architectural components, interfaces, design, implementation,
#
#
# Document 17
# CWE-1053: Missing Documentation for Design
# Description: The product does not have documentation that represents how it is designed.
#
# Document 18
# ATM Technique: System Information Discovery
# Description: <p>An adversary may attempt to get detailed information about the ECU’s operating system and hardware, including version, patches, hotfixes, service packs, and architecture. Adversaries may use the information from&nbsp;this technique&nbsp;during automated discovery to shape follow-on behaviors, including whether or not the adversary fully i
#
# Document 19
# MITRE Technique: Remote System Information Discovery
# Description: An adversary may attempt to get detailed information about remote systems and their peripherals, such as make/model, role, and configuration. Adversaries may use information from Remote System Information Discovery to aid in targeting and shaping follow-on behaviors. For example, the system's operational role and model information c
#
# Document 20
# ATM Technique: Input Prompt
# Description: <p>The operating system and installed applications often have legitimate needs to prompt the user for sensitive information such as account credentials, bank account information, or Personally Identifiable Information (PII). Adversaries may mimic this functionality to prompt users for sensitive information.</p><p>Compared to traditional PCs, the constrained
#
# Document 21
# CAPEC-548:
# Description: An adversary contaminates organizational information systems (including devices and networks) by causing them to handle information of a classification/sensitivity for which they have not been authorized. When this happens, the contaminated information system, device, or network must be brought offline to investigate and mitigate the data spill, which denies availability o
#
# Document 22
# CWE-1097: Persistent Storable Data Element without Associated Comparison Control Element
# Description: The product uses a storable data element that does not have
# 					all of the associated functions or methods that are necessary to support
# 					comparison.
#
# Document 23
# MITRE Technique: Manipulate I/O Image
# Description: Adversaries may manipulate the I/O image of PLCs through various means to prevent them from functioning as expected. Methods of I/O image manipulation may include overriding the I/O table via direct memory manipulation or using the override function used for testing PLC programs. (Citation: Dr. Kelvin T. Erickson December 2010) During the scan cyc
#
# Document 24
# MITRE Technique: Point & Tag Identification
# Description: Adversaries may collect point and tag values to gain a more comprehensive understanding of the process environment. Points may be values such as inputs, memory locations, outputs or other process specific variables. (Citation: Dennis L. Sloatman September 2016) Tags are the identifiers given to points for operator convenience.
#
# Collecting s
#
# Document 25
# MITRE Technique: Data from Information Repositories
# Description: Adversaries may target and collect data from information repositories. This can include sensitive data such as specifications, schematics, or diagrams of control system layouts, devices, and processes. Examples of information repositories include reference databases in the process environment, as well as databases in the corporate ne
#
# Document 26
# ATM Technique: Aftermarket, Customer, or Dealer Equipment
# Description: <p>Adversaries may take use aftermarket, customer, or dealer equipment as an initial access point into the vehicle.&nbsp;Paired devices, such as a customer's smart phone, often possess valid credentials for the vehicle’s Bluetooth and Wi-Fi networks, access to phone projection technologies, and may be connected to USB ports. De
#
# Document 27
# MITRE Technique: Monitor Process State
# Description: Adversaries may gather information about the physical process state. This information may be used to gain more information about the process itself or used as a trigger for malicious actions. The sources of process state information may vary such as, OPC tags, historian data, specific PLC block information, or network traffic.
#
# Document 28
# MITRE Technique: I/O Image
# Description: Adversaries may seek to capture process values related to the inputs and outputs of a PLC. During the scan cycle, a PLC reads the status of all inputs and stores them in an image table. (Citation: Nanjundaiah, Vaidyanath) The image table is the PLCs internal storage location where values of inputs/outputs for one scan are stored while it executes the user pr
#
# Document 29
# ATM Technique: Access personal data
# Description: <p>An adversary could attempt to access the vehicle occupants' personal data. This could include calendar entries, call logs, contact lists, media playlists, or notifications (including SMS messages, emails, etc.).</p><p>An adversary could also attempt to access occupants' personal data via an ECU’s application data for apps such as Facebook or Gmai
#
# Document 30
# CWE-1110: Incomplete Design Documentation
# Description: The product's design documentation does not adequately describe
# 					control flow, data flow, system initialization, relationships between tasks,
# 					components, rationales, or other important aspects of the
# 					design.
#
# Document 31
# CWE-312: Cleartext Storage of Sensitive Information
# Description: The product stores sensitive information in cleartext within a resource that might be accessible to another control sphere.
#
# Document 32
# CWE-488: Exposure of Data Element to Wrong Session
# Description: The product does not sufficiently enforce boundaries between the states of different sessions, causing data to be provided to, or used by, the wrong session.
#
# Document 33
# MITRE Technique: Detect Program State
# Description: Adversaries may seek to gather information about the current state of a program on a PLC. State information reveals information about the program, including whether it's running, halted, stopped, or has generated an exception. This information may be leveraged as a verification of malicious program execution or to determine if a PLC is ready to do
#
# Document 34
# CWE-1092: Use of Same Invokable Control Element in Multiple Architectural Layers
# Description: The product uses the same control element across multiple
# 					architectural layers.
#
# Document 35
# CWE-237: Improper Handling of Structural Elements
# Description: The product does not handle or incorrectly handles inputs that are related to complex structures.
#
# Document 36
# MITRE Technique: I/O Module Discovery
# Description: Adversaries may use input/output (I/O) module discovery to gather key information about a control system device. An I/O module is a device that allows the control system device to either receive or send signals to other devices. These signals can be analog or digital, and may support a number of different protocols. Devices are often able to use a
#
# Document 37
# MITRE Technique: Remote System Discovery
# Description: Adversaries may attempt to get a listing of other systems by IP address, hostname, or other logical identifier on a network that may be used for subsequent Lateral Movement or Discovery techniques. Functionality could exist within adversary tools to enable this, but utilities available on the operating system or vendor software could also be us
#
# Document 38
# CWE-1065: Runtime Resource Management Control Element in a Component Built to Run on Application Servers
# Description: The product uses deployed components from application servers, but it also uses low-level functions/methods for management of resources, instead of the API provided by the application server.
#
# Document 39
# CWE-360: Trust of System Event Data
# Description: Security based on event locations are insecure and can be spoofed.
#
# Document 40
# MITRE Technique: Theft of Operational Information
# Description: Adversaries may steal operational information on a production environment as a direct mission outcome for personal gain or to inform future operations. This information may include design documents, schedules, rotational data, or similar artifacts that provide insight on operations.    In the Bowman Dam incident, adversaries probed sys

# %%
result = basic_rag_pipeline.run(
    {
        "text_embedder": {"text": user_query},
        "prompt_builder": {
            "question": user_query
        }
    }
)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# output in json format

# %%
response = result["llm"]["replies"][0]

print(response)
# Out:
# ```json
# {
#   "assets": {
#     "_id": "6b1a3f7d-4d3b-4b1a-8f1a-3a1b4d7f9a0b",
#     "user_id": "your_user_id",
#     "model_id": "infotainment_tara_model",
#     "template": {
#       "nodes": [
#         {
#           "id": "infotainment_ecu",
#           "type": "component",
#           "parentId": "",
#           "isAsset": true,
#           "data": {
#             "label": "Infotainment ECU",
#             "description": "Central processing unit for infotainment system functions."
#           },
#           "properties": [
#             "Integrity",
#             "Confidentiality",
#             "Availability"
#           ],
#           "style": {
#             "width": 200,
#             "height": 80
#           },
#           "position": {
#             "x": 300,
#             "y": 100
#           }
#         },
#         {
#           "id": "hmi_display",
#           "type": "component",
#           "parentId": "infotainment_ecu",
#           "isAsset": true,
#           "data": {
#             "label": "HMI Display",
#             "description": "Visual interface for user interaction."
#           },
#           "properties": [
#             "Integrity",
#             "Confidentiality",
#             "Availability"
#           ],
#           "style": {
#             "width": 150,
#             "height": 60
#           },
#           "position": {
#             "x": 300,
#             "y": 250
#           }
#         },
#         {
#           "id": "audio_amplifier",
#           "type": "component",
#           "parentId": "infotainment_ecu",
#           "isAsset": true,
#           "data": {
#             "label": "Audio Amplifier",
#             "description": "Processes and amplifies audio signals."
#           },
#           "properties": [
#             "Integrity",
#             "Availability"
#           ],
#           "style": {
#             "width": 150,
#             "height": 60
#           },
#           "position": {
#             "x": 500,
#             "y": 250
#           }
#         },
#         {
#           "id": "navigation_module",
#           "type": "component",
#           "parentId": "infotainment_ecu",
#           "isAsset": true,
#           "data": {
#             "label": "Navigation Module",
#             "description": "Provides GPS and navigation services."
#           },
#           "properties": [
#             "Integrity",
#             "Confidentiality",
#             "Availability"
#           ],
#           "style": {
#             "width": 150,
#             "height": 60
#           },
#           "position": {
#             "x": 100,
#             "y": 250
#           }
#         },
#         {
#           "id": "bluetooth_module",
#           "type": "component",
#           "parentId": "infotainment_ecu",
#           "isAsset": true,
#           "data": {
#             "label": "Bluetooth Module",
#             "description": "Enables wireless connectivity for devices."
#           },
#           "properties": [
#             "Integrity",
#             "Confidentiality",
#             "Availability"
#           ],
#           "style": {
#             "width": 150,
#             "height": 60
#           },
#           "position": {
#             "x": 700,
#             "y": 250
#           }
#         },
#         {
#           "id": "usb_interface",
#           "type": "component",
#           "parentId": "infotainment_ecu",
#           "isAsset": true,
#           "data": {
#             "label": "USB Interface",
#             "description": "Port for connecting external storage and devices."
#           },
#           "properties": [
#             "Integrity",
#             "Confidentiality",
#             "Availability"
#           ],
#           "style": {
#             "width": 150,
#             "height": 60
#           },
#           "position": {
#             "x": 100,
#             "y": 400
#           }
#         },
#         {
#           "id": "wifi_module",
#           "type": "component",
#           "parentId": "infotainment_ecu",
#           "isAsset": true,
#           "data": {
#             "label": "WiFi Module",
#             "description": "Enables wireless network connectivity."
#           },
#           "properties": [
#             "Integrity",
#             "Confidentiality",
#             "Availability"
#           ],
#           "style": {
#             "width": 150,
#             "height": 60
#           },
#           "position": {
#             "x": 300,
#             "y": 400
#           }
#         },
#         {
#           "id": "cellular_module",
#           "type": "component",
#           "parentId": "infotainment_ecu",
#           "isAsset": true,
#           "data": {
#             "label": "Cellular Module",
#             "description": "Provides cellular network connectivity (e.g., for updates, remote services)."
#           },
#           "properties": [
#             "Integrity",
#             "Confidentiality",
#             "Availability"
#           ],
#           "style": {
#             "width": 150,
#             "height": 60
#           },
#           "position": {
#             "x": 500,
#             "y": 400
#           }
#         },
#         {
#           "id": "microphone",
#           "type": "component",
#           "parentId": "infotainment_ecu",
#           "isAsset": true,
#           "data": {
#             "label": "Microphone",
#             "description": "Captures voice input for commands or calls."
#           },
#           "properties": [
#             "Integrity",
#             "Confidentiality",
#             "Availability"
#           ],
#           "style": {
#             "width": 150,
#             "height": 60
#           },
#           "position": {
#             "x": 700,
#             "y": 400
#           }
#         },
#         {
#           "id": "speaker",
#           "type": "component",
#           "parentId": "audio_amplifier",
#           "isAsset": true,
#           "data": {
#             "label": "Speaker",
#             "description": "Outputs audio to the vehicle occupants."
#           },
#           "properties": [
#             "Integrity",
#             "Availability"
#           ],
#           "style": {
#             "width": 150,
#             "height": 60
#           },
#           "position": {
#             "x": 500,
#             "y": 550
#           }
#         },
#         {
#           "id": "external_audio_source",
#           "type": "component",
#           "parentId": "infotainment_ecu",
#           "isAsset": true,
#           "data": {
#             "label": "External Audio Source",
#             "description": "Interface for external audio input (e.g., aux input)."
#           },
#           "properties": [
#             "Integrity",
#             "Availability"
#           ],
#           "style": {
#             "width": 150,
#             "height": 60
#           },
#           "position": {
#             "x": 300,
#             "y": 550
#           }
#         },
#         {
#           "id": "vehicle_bus_gateway",
#           "type": "component",
#           "parentId": "",
#           "isAsset": true,
#           "data": {
#             "label": "Vehicle Bus Gateway",
#             "description": "Interface to other vehicle networks (CAN, Ethernet)."
#           },
#           "properties": [
#             "Integrity",
#             "Confidentiality",
#             "Availability"
#           ],
#           "style": {
#             "width": 200,
#             "height": 80
#           },
#           "position": {
#             "x": 300,
#             "y": 700
#           }
#         }
#       ],
#       "edges": [
#         {
#           "id": "infotainment_ecu_to_hmi_display",
#           "source": "infotainment_ecu",
#           "target": "hmi_display",
#           "type": "smoothstep",
#           "data": {
#             "label": "controls display"
#           }
#         },
#         {
#           "id": "infotainment_ecu_to_audio_amplifier",
#           "source": "infotainment_ecu",
#           "target": "audio_amplifier",
#           "type": "smoothstep",
#           "data": {
#             "label": "audio output"
#           }
#         },
#         {
#           "id": "infotainment_ecu_to_navigation_module",
#           "source": "infotainment_ecu",
#           "target": "navigation_module",
#           "type": "smoothstep",
#           "data": {
#             "label": "uses navigation data"
#           }
#         },
#         {
#           "id": "infotainment_ecu_to_bluetooth_module",
#           "source": "infotainment_ecu",
#           "target": "bluetooth_module",
#           "type": "smoothstep",
#           "data": {
#             "label": "manages bluetooth"
#           }
#         },
#         {
#           "id": "infotainment_ecu_to_usb_interface",
#           "source": "infotainment_ecu",
#           "target": "usb_interface",
#           "type": "smoothstep",
#           "data": {
#             "label": "manages usb"
#           }
#         },
#         {
#           "id": "infotainment_ecu_to_wifi_module",
#           "source": "infotainment_ecu",
#           "target": "wifi_module",
#           "type": "smoothstep",
#           "data": {
#             "label": "manages wifi"
#           }
#         },
#         {
#           "id": "infotainment_ecu_to_cellular_module",
#           "source": "infotainment_ecu",
#           "target": "cellular_module",
#           "type": "smoothstep",
#           "data": {
#             "label": "manages cellular"
#           }
#         },
#         {
#           "id": "infotainment_ecu_to_microphone",
#           "source": "infotainment_ecu",
#           "target": "microphone",
#           "type": "smoothstep",
#           "data": {
#             "label": "audio input"
#           }
#         },
#         {
#           "id": "audio_amplifier_to_speaker",
#           "source": "audio_amplifier",
#           "target": "speaker",
#           "type": "smoothstep",
#           "data": {
#             "label": "amplified audio"
#           }
#         },
#         {
#           "id": "infotainment_ecu_to_external_audio_source",
#           "source": "infotainment_ecu",
#           "target": "external_audio_source",
#           "type": "smoothstep",
#           "data": {
#             "label": "audio input"
#           }
#         },
#         {
#           "id": "infotainment_ecu_to_vehicle_bus_gateway",
#           "source": "infotainment_ecu",
#           "target": "vehicle_bus_gateway",
#           "type": "smoothstep",
#           "data": {
#             "label": "communicates with vehicle network"
#           }
#         },
#         {
#           "id": "navigation_module_to_vehicle_bus_gateway",
#           "source": "navigation_module",
#           "target": "vehicle_bus_gateway",
#           "type": "smoothstep",
#           "data": {
#             "label": "uses vehicle data"
#           }
#         },
#         {
#           "id": "bluetooth_module_to_vehicle_bus_gateway",
#           "source": "bluetooth_module",
#           "target": "vehicle_bus_gateway",
#           "type": "smoothstep",
#           "data": {
#             "label": "uses vehicle data"
#           }
#         },
#         {
#           "id": "usb_interface_to_vehicle_bus_gateway",
#           "source": "usb_interface",
#           "target": "vehicle_bus_gateway",
#           "type": "smoothstep",
#           "data": {
#             "label": "uses vehicle data"
#           }
#         },
#         {
#           "id": "wifi_module_to_vehicle_bus_gateway",
#           "source": "wifi_module",
#           "target": "vehicle_bus_gateway",
#           "type": "smoothstep",
#           "data": {
#             "label": "uses vehicle data"
#           }
#         },
#         {
#           "id": "cellular_module_to_vehicle_bus_gateway",
#           "source": "cellular_module",
#           "target": "vehicle_bus_gateway",
#           "type": "smoothstep",
#           "data": {
#             "label": "uses vehicle data"
#           }
#         }
#       ],
#       "details": [
#         {
#           "nodeId": "infotainment_ecu",
#           "name": "Infotainment ECU",
#           "desc": "The central processing unit for the infotainment system.",
#           "type": "ECU",
#           "props": [
#             {
#               "name": "Integrity",
#               "id": "prop_integrity"
#             },
#             {
#               "name": "Confidentiality",
#               "id": "prop_confidentiality"
#             },
#             {
#               "name": "Availability",
#               "id": "prop_availability"
#             }
#           ]
#         },
#         {
#           "nodeId": "hmi_display",
#           "name": "HMI Display",
#           "desc": "The visual interface for user interaction and information display.",
#           "type": "HMI Component",
#           "props": [
#             {
#               "name": "Integrity",
#               "id": "prop_integrity"
#             },
#             {
#               "name": "Confidentiality",
#               "id": "prop_confidentiality"
#             },
#             {
#               "name": "Availability",
#               "id": "prop_availability"
#             }
#           ]
#         },
#         {
#           "nodeId": "audio_amplifier",
#           "name": "Audio Amplifier",
#           "desc": "Responsible for amplifying audio signals to drive speakers.",
#           "type": "Audio Component",
#           "props": [
#             {
#               "name": "Integrity",
#               "id": "prop_integrity"
#             },
#             {
#               "name": "Availability",
#               "id": "prop_availability"
#             }
#           ]
#         },
#         {
#           "nodeId": "navigation_module",
#           "name": "Navigation Module",
#           "desc": "Provides GPS positioning and navigation route calculation.",
#           "type": "Module",
#           "props": [
#             {
#               "name": "Integrity",
#               "id": "prop_integrity"
#             },
#             {
#               "name": "Confidentiality",
#               "id": "prop_confidentiality"
#             },
#             {
#               "name": "Availability",
#               "id": "prop_availability"
#             }
#           ]
#         },
#         {
#           "nodeId": "bluetooth_module",
#           "name": "Bluetooth Module",
#           "desc": "Handles wireless communication with user devices via Bluetooth.",
#           "type": "Connectivity Module",
#           "props": [
#             {
#               "name": "Integrity",
#               "id": "prop_integrity"
#             },
#             {
#               "name": "Confidentiality",
#               "id": "prop_confidentiality"
#             },
#             {
#               "name": "Availability",
#               "id": "prop_availability"
#             }
#           ]
#         },
#         {
#           "nodeId": "usb_interface",
#           "name": "USB Interface",
#           "desc": "Allows connection of external USB devices for media playback or data transfer.",
#           "type": "Interface",
#           "props": [
#             {
#               "name": "Integrity",
#               "id": "prop_integrity"
#             },
#             {
#               "name": "Confidentiality",
#               "id": "prop_confidentiality"
#             },
#             {
#               "name": "Availability",
#               "id": "prop_availability"
#             }
#           ]
#         },
#         {
#           "nodeId": "wifi_module",
#           "name": "WiFi Module",
#           "desc": "Enables wireless local area network connectivity for internet access or system updates.",
#           "type": "Connectivity Module",
#           "props": [
#             {
#               "name": "Integrity",
#               "id": "prop_integrity"
#             },
#             {
#               "name": "Confidentiality",
#               "id": "prop_confidentiality"
#             },
#             {
#               "name": "Availability",
#               "id": "prop_availability"
#             }
#           ]
#         },
#         {
#           "nodeId": "cellular_module",
#           "name": "Cellular Module",
#           "desc": "Provides wide area network connectivity via cellular networks for remote services or data streaming.",
#           "type": "Connectivity Module",
#           "props": [
#             {
#               "name": "Integrity",
#               "id": "prop_integrity"
#             },
#             {
#               "name": "Confidentiality",
#               "id": "prop_confidentiality"
#             },
#             {
#               "name": "Availability",
#               "id": "prop_availability"
#             }
#           ]
#         },
#         {
#           "nodeId": "microphone",
#           "name": "Microphone",
#           "desc": "Captures audio input for voice commands, calls, or voice assistants.",
#           "type": "Input Component",
#           "props": [
#             {
#               "name": "Integrity",
#               "id": "prop_integrity"
#             },
#             {
#               "name": "Confidentiality",
#               "id": "prop_confidentiality"
#             },
#             {
#               "name": "Availability",
#               "id": "prop_availability"
#             }
#           ]
#         },
#         {
#           "nodeId": "speaker",
#           "name": "Speaker",
#           "desc": "Outputs audio from the infotainment system to the vehicle occupants.",
#           "type": "Output Component",
#           "props": [
#             {
#               "name": "Integrity",
#               "id": "prop_integrity"
#             },
#             {
#               "name": "Availability",
#               "id": "prop_availability"
#             }
#           ]
#         },
#         {
#           "nodeId": "external_audio_source",
#           "name": "External Audio Source",
#           "desc": "Interface for audio input from external devices (e.g., AUX port).",
#           "type": "Input Component",
#           "props": [
#             {
#               "name": "Integrity",
#               "id": "prop_integrity"
#             },
#             {
#               "name": "Availability",
#               "id": "prop_availability"
#             }
#           ]
#         },
#         {
#           "nodeId": "vehicle_bus_gateway",
#           "name": "Vehicle Bus Gateway",
#           "desc": "Connects the infotainment system to other vehicle networks (e.g., CAN bus) for data exchange.",
#           "type": "Gateway",
#           "props": [
#             {
#               "name": "Integrity",
#               "id": "prop_integrity"
#             },
#             {
#               "name": "Confidentiality",
#               "id": "prop_confidentiality"
#             },
#             {
#               "name": "Availability",
#               "id": "prop_availability"
#             }
#           ]
#         }
#       ]
#     }
#   },
#   "damage_scenarios": {
#     "_id": "e7d2c0e5-4c2b-4a1f-8b0e-7a1b3d5f9c0a",
#     "model_id": "infotainment_tara_model",
#     "type": "damage",
#     "derivation": [
#       {
#         "id": "ds_001",
#         "nodeId": "hmi_display",
#         "task": "Threat Analysis",
#         "name": "Display of False Information",
#         "loss": "Misleading the driver, potential safety hazard.",
#         "asset": "HMI Display",
#         "damage_scene": "An attacker exploits a vulnerability (e.g., CWE-1083: Data Access from Outside Expected Data Manager Component) to manipulate the displayed information, showing incorrect speed, navigation directions, or warning messages.",
#         "isChecked": false
#       },
#       {
#         "id": "ds_002",
#         "nodeId": "infotainment_ecu",
#         "task": "Threat Analysis",
#         "name": "Unauthorized Access to Personal Data",
#         "loss": "Privacy breach of user data (contacts, call history, saved locations).",
#         "asset": "Infotainment ECU",
#         "damage_scene": "Adversaries may attempt to access personal data stored on the infotainment system (ATM Technique: Access personal data) by exploiting vulnerabilities related to insecure data storage (CWE-312: Cleartext Storage of Sensitive Information) or improper access controls.",
#         "isChecked": false
#       },
#       {
#         "id": "ds_003",
#         "nodeId": "microphone",
#         "task": "Threat Analysis",
#         "name": "Unauthorized Audio Interception",
#         "loss": "Eavesdropping on conversations inside the vehicle.",
#         "asset": "Microphone",
#         "damage_scene": "An attacker gains control of the microphone (e.g., via MITRE Technique: Screen Capture or a compromise of the ECU) to record conversations within the vehicle.",
#         "isChecked": false
#       },
#       {
#         "id": "ds_004",
#         "nodeId": "bluetooth_module",
#         "task": "Threat Analysis",
#         "name": "Malicious Device Pairing",
#         "loss": "Compromise of infotainment system, access to vehicle data, or spread of malware.",
#         "asset": "Bluetooth Module",
#         "damage_scene": "Attacker forces unauthorized pairing with the Bluetooth module, potentially gaining access to the infotainment system and connected devices (CAPEC-548: Contamination of Information Systems).",
#         "isChecked": false
#       },
#       {
#         "id": "ds_005",
#         "nodeId": "usb_interface",
#         "task": "Threat Analysis",
#         "name": "Malicious USB Drive Infection",
#         "loss": "Introduction of malware into the infotainment system, potentially spreading to other vehicle ECUs.",
#         "asset": "USB Interface",
#         "damage_scene": "An attacker uses a specially crafted USB drive to exploit vulnerabilities when connected, leading to malware execution (CWE-237: Improper Handling of Structural Elements).",
#         "isChecked": false
#       },
#       {
#         "id": "ds_006",
#         "nodeId": "wifi_module",
#         "task": "Threat Analysis",
#         "name": "Denial of Service (DoS) on Wi-Fi",
#         "loss": "Disruption of internet connectivity, preventing updates and connected services.",
#         "asset": "WiFi Module",
#         "damage_scene": "An attacker floods the Wi-Fi module with traffic, causing a Denial of Service and preventing legitimate network operations (similar to MITRE Technique: Automated Collection, but for disruption).",
#         "isChecked": false
#       },
#       {
#         "id": "ds_007",
#         "nodeId": "cellular_module",
#         "task": "Threat Analysis",
#         "name": "Interception of Over-the-Air (OTA) Updates",
#         "loss": "Installation of malicious firmware or manipulation of system configuration.",
#         "asset": "Cellular Module",
#         "damage_scene": "An attacker intercepts or manipulates OTA update packets sent over the cellular network, leading to the installation of compromised firmware (CWE-15: External Control of System or Configuration Setting).",
#         "isChecked": false
#       },
#       {
#         "id": "ds_008",
#         "nodeId": "infotainment_ecu",
#         "task": "Threat Analysis",
#         "name": "Tampering with Vehicle Telemetry",
#         "loss": "Incorrect vehicle data reported to other ECUs or remote services, potentially affecting driving behavior or diagnostics.",
#         "asset": "Infotainment ECU",
#         "damage_scene": "An attacker gains access to the infotainment system and manipulates the telemetry data it would normally relay to other ECUs (ATM Technique: Access vehicle telemetry) via the vehicle bus gateway (CWE-1251: Mirrored Regions with Different Values).",
#         "isChecked": false
#       },
#       {
#         "id": "ds_009",
#         "nodeId": "audio_amplifier",
#         "task": "Threat Analysis",
#         "name": "Distorted or Excessive Audio Output",
#         "loss": "Annoyance to occupants, potential hearing damage, distraction to the driver.",
#         "asset": "Audio Amplifier",
#         "damage_scene": "An attacker manipulates audio output settings or sends malformed audio data, causing the amplifier to produce distorted or excessively loud sound (CWE-915: Improperly Controlled Modification of Dynamically-Determined Object Attributes).",
#         "isChecked": false
#       },
#       {
#         "id": "ds_010",
#         "nodeId": "navigation_module",
#         "task": "Threat Analysis",
#         "name": "Incorrect Navigation Guidance",
#         "loss": "Driver disorientation, taking wrong routes, potential safety risks.",
#         "asset": "Navigation Module",
#         "damage_scene": "An attacker corrupts the navigation data or GPS signals received by the module, leading to incorrect route calculations and misleading directions (ATM Technique: Gather Target Information – from Vehicle, by manipulating target data).",
#         "isChecked": false
#       },
#       {
#         "id": "ds_011",
#         "nodeId": "vehicle_bus_gateway",
#         "task": "Threat Analysis",
#         "name": "Replay of Control Commands",
#         "loss": "Unintended vehicle behavior, potential safety hazards.",
#         "asset": "Vehicle Bus Gateway",
#         "damage_scene": "An attacker captures legitimate communication packets between the infotainment system and other ECUs via the gateway and replays them to cause unintended actions (MITRE Technique: Manipulate I/O Image, applied to command data).",
#         "isChecked": false
#       },
#       {
#         "id": "ds_012",
#         "nodeId": "hmi_display",
#         "task": "Threat Analysis",
#         "name": "Screen Capture for Sensitive Information",
#         "loss": "Disclosure of sensitive information (e.g., login credentials, personal data displayed).",
#         "asset": "HMI Display",
#         "damage_scene": "An attacker uses a screen capture capability (MITRE Technique: Screen Capture) to steal sensitive information being displayed on the infotainment screen.",
#         "isChecked": false
#       },
#       {
#         "id": "ds_013",
#         "nodeId": "infotainment_ecu",
#         "task": "Threat Analysis",
#         "name": "Exploitation of External Control Settings",
#         "loss": "Unauthorized modification of system configurations, leading to potential security breaches or degraded functionality.",
#         "asset": "Infotainment ECU",
#         "damage_scene": "An attacker exploits vulnerabilities that allow external control over system configuration settings (CWE-15: External Control of System or Configuration Setting), altering operational parameters.",
#         "isChecked": false
#       },
#       {
#         "id": "ds_014",
#         "nodeId": "infotainment_ecu",
#         "task": "Threat Analysis",
#         "name": "Cleartext Storage of Sensitive GUI Information",
#         "loss": "Exposure of sensitive information displayed in the GUI, such as user credentials or sensitive data.",
#         "asset": "Infotainment ECU",
#         "damage_scene": "Sensitive information is stored in cleartext within the GUI elements, making it vulnerable to extraction if the system is compromised (CWE-317: Cleartext Storage of Sensitive Information in GUI).",
#         "isChecked": false
#       }
#     ],
#     "details": [
#       {
#         "nodeId": "hmi_display",
#         "name": "Display of False Information",
#         "desc": "An attacker manipulates displayed information on the HMI, leading to driver misdirection.",
#         "type": "Information Manipulation",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "prop_integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "prop_confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "prop_availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "infotainment_ecu",
#         "name": "Unauthorized Access to Personal Data",
#         "desc": "Attacker gains unauthorized access to sensitive user data stored within the ECU.",
#         "type": "Data Breach",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "prop_integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "prop_confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "prop_availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "microphone",
#         "name": "Unauthorized Audio Interception",
#         "desc": "Attacker activates the microphone to eavesdrop on vehicle occupants.",
#         "type": "Privacy Violation",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "prop_integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "prop_confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "prop_availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "bluetooth_module",
#         "name": "Malicious Device Pairing",
#         "desc": "Attacker pairs a malicious device with the Bluetooth module to gain unauthorized access.",
#         "type": "Unauthorized Access",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "prop_integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "prop_confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "prop_availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "usb_interface",
#         "name": "Malicious USB Drive Infection",
#         "desc": "Introduction of malware into the system via a compromised USB drive.",
#         "type": "Malware Injection",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "prop_integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "prop_confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "prop_availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "wifi_module",
#         "name": "Denial of Service (DoS) on Wi-Fi",
#         "desc": "Attacker disrupts Wi-Fi connectivity, preventing access to network resources.",
#         "type": "Denial of Service",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "prop_integrity"
#           },
#           {
#             "name": "Availability",
#             "id": "prop_availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "cellular_module",
#         "name": "Interception of Over-the-Air (OTA) Updates",
#         "desc": "Attacker intercepts or manipulates OTA updates to install malicious firmware.",
#         "type": "Firmware Tampering",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "prop_integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "prop_confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "prop_availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "infotainment_ecu",
#         "name": "Tampering with Vehicle Telemetry",
#         "desc": "Attacker manipulates vehicle telemetry data reported by the infotainment system.",
#         "type": "Data Manipulation",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "prop_integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "prop_confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "prop_availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "audio_amplifier",
#         "name": "Distorted or Excessive Audio Output",
#         "desc": "Attacker causes the audio amplifier to produce distorted or excessively loud sound.",
#         "type": "Audio Output Manipulation",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "prop_integrity"
#           },
#           {
#             "name": "Availability",
#             "id": "prop_availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "navigation_module",
#         "name": "Incorrect Navigation Guidance",
#         "desc": "Attacker corrupts navigation data or GPS signals, leading to incorrect route information.",
#         "type": "Navigation Tampering",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "prop_integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "prop_confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "prop_availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "vehicle_bus_gateway",
#         "name": "Replay of Control Commands",
#         "desc": "Attacker replays captured communication packets to trigger unintended actions.",
#         "type": "Command Replay",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "prop_integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "prop_confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "prop_availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "hmi_display",
#         "name": "Screen Capture for Sensitive Information",
#         "desc": "Attacker uses screen capture to steal sensitive information displayed on the HMI.",
#         "type": "Information Disclosure",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "prop_integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "prop_confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "prop_availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "infotainment_ecu",
#         "name": "Exploitation of External Control Settings",
#         "desc": "Attacker exploits vulnerabilities to externally control system configuration settings.",
#         "type": "Configuration Tampering",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "prop_integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "prop_confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "prop_availability"
#           }
#         ]
#       },
#       {
#         "nodeId": "infotainment_ecu",
#         "name": "Cleartext Storage of Sensitive GUI Information",
#         "desc": "Sensitive information stored in cleartext within GUI elements is exposed.",
#         "type": "Information Disclosure",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "prop_integrity"
#           },
#           {
#             "name": "Confidentiality",
#             "id": "prop_confidentiality"
#           },
#           {
#             "name": "Availability",
#             "id": "prop_availability"
#           }
#         ]
#       }
#     ]
#   }
# }
# ```
