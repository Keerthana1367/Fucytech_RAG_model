# %% [markdown]
# ## STEP 1 — INSTALL DEPENDENCIES

# %%
# %%bash
# pip install -q haystack-ai
# pip install -q "sentence-transformers>=2.2.0"
# pip install -q google-ai-haystack
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 672.4/672.4 kB 13.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.7/198.7 kB 13.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 4.2 MB/s eta 0:00:00

# %% [markdown]
# ## STEP 2 — IMPORTS

# %%
import os
import json

from haystack import Pipeline, Document
from haystack.document_stores.in_memory import InMemoryDocumentStore
from haystack.components.embedders import (
    SentenceTransformersDocumentEmbedder,
    SentenceTransformersTextEmbedder,
)
from haystack.components.retrievers.in_memory import InMemoryEmbeddingRetriever
from haystack.components.builders import PromptBuilder
from haystack_integrations.components.generators.google_ai import GoogleAIGeminiGenerator

print("Imports complete.")
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)
# Imports complete.

# %% [markdown]
# ## STEP 3 — DOCUMENT STORE & EMBEDDER SETUP

# %%
document_store = InMemoryDocumentStore()

MODEL = "sentence-transformers/all-MiniLM-L6-v2"
doc_embedder  = SentenceTransformersDocumentEmbedder(model=MODEL)
text_embedder = SentenceTransformersTextEmbedder(model=MODEL)
doc_embedder.warm_up()

# top_k=50 so broad queries ("all damage scenarios") pull sufficient context
retriever = InMemoryEmbeddingRetriever(document_store=document_store, top_k=50)
print("Setup complete.")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Setup complete.

# %% [markdown]
# ## STEP 4 — DATA INGESTION
#
# Stores **full** node and edge objects (including `style`) so the LLM can reproduce them exactly.
# Only UI-state fields that carry zero semantic value are stripped:
# `dragging`, `resizing`, `selected` (boolean interaction states, not data).
#
# Everything else — including `style`, `position`, `positionAbsolute`, `height`, `width`,
# `isAsset`, `parentId`, `properties`, `markerStart`, `markerEnd` — is preserved.

# %%
ITEM_PATH   = "item_defination.json"
DAMAGE_PATH = "Damage_scenarios.json"

# Only strip pure interaction-state booleans that carry no semantic value
NODE_STRIP = {"dragging", "resizing", "selected"}
EDGE_STRIP = {"selected"}

def clean_node(node):
    """Strip interaction-state keys only; preserve style and all data fields."""
    return {k: v for k, v in node.items() if k not in NODE_STRIP}

def clean_edge(edge):
    """Strip interaction-state keys only."""
    return {k: v for k, v in edge.items() if k not in EDGE_STRIP}

docs = []

# ===========================================================================
# DATASET 1 — item_defination.json
# Each node -> 1 Document  |  Each edge -> 1 Document
# ===========================================================================
with open(ITEM_PATH, "r", encoding="utf-8") as f:
    item_data = json.load(f)

model_name = item_data["Models"][0]["name"] if item_data.get("Models") else "unknown"
model_id   = item_data["Models"][0]["_id"]  if item_data.get("Models") else None

item_start = len(docs)
for asset in item_data.get("Assets", []):
    asset_id = asset.get("_id")
    template = asset.get("template", {})

    for node in template.get("nodes", []):
        cn = clean_node(node)
        docs.append(Document(
            content=json.dumps(cn, ensure_ascii=False),
            meta={
                "source":     "item_definition",
                "type":       "node",
                "model_name": model_name,
                "model_id":   model_id,
                "asset_id":   asset_id,
                "node_id":    node.get("id"),
                "node_label": node.get("data", {}).get("label", ""),
            }
        ))

    for edge in template.get("edges", []):
        ce = clean_edge(edge)
        docs.append(Document(
            content=json.dumps(ce, ensure_ascii=False),
            meta={
                "source":      "item_definition",
                "type":        "edge",
                "model_id":    model_id,
                "asset_id":    asset_id,
                "edge_id":     edge.get("id"),
                "source_node": edge.get("source"),
                "target_node": edge.get("target"),
            }
        ))

print(f"Item Definition  -> {len(docs) - item_start} docs (nodes + edges)")

# ===========================================================================
# DATASET 2 — Damage_scenarios.json
# Each Derivation -> 1 Document  |  Each Detail -> 1 Document
# ===========================================================================
with open(DAMAGE_PATH, "r", encoding="utf-8") as f:
    damage_data = json.load(f)

damage_start = len(docs)
for ds in damage_data.get("Damage_scenarios", []):
    ds_type  = ds.get("type", "")
    ds_id    = ds.get("_id")
    ds_model = ds.get("model_id")

    for deriv in ds.get("Derivations", []):
        docs.append(Document(
            content=json.dumps(deriv, ensure_ascii=False),
            meta={
                "source":    "damage_scenarios",
                "type":      "derivation",
                "ds_type":   ds_type,
                "ds_id":     ds_id,
                "model_id":  ds_model,
                "ds_id_ref": deriv.get("id"),
                "node_id":   deriv.get("nodeId"),
            }
        ))

    for detail in (ds.get("Details", []) or []):
        docs.append(Document(
            content=json.dumps(detail, ensure_ascii=False),
            meta={
                "source":   "damage_scenarios",
                "type":     "detail",
                "ds_type":  ds_type,
                "ds_id":    ds_id,
                "model_id": ds_model,
                "node_id":  detail.get("nodeId"),
                "name":     detail.get("Name") or detail.get("name"),
            }
        ))

print(f"Damage Scenarios -> {len(docs) - damage_start} docs (derivations + details)")
print(f"Total            -> {len(docs)} documents")

embedded_docs = doc_embedder.run(documents=docs)["documents"]
document_store.write_documents(embedded_docs)
print(f"All {len(embedded_docs)} documents embedded and stored.")
# Out:
# Item Definition  -> 25 docs (nodes + edges)
# Damage Scenarios -> 76 docs (derivations + details)
# Total            -> 101 documents
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# All 101 documents embedded and stored.

# %% [markdown]
# ## STEP 5 — PROMPT TEMPLATE (NATURAL LANGUAGE INTERPRETER + NATIVE STRUCTURE MIRROR)

# %%
template = """
You are an intelligent JSON data extraction engine for a BMS (Battery Management System) TARA knowledge base.

You will receive:
1. Context documents — raw JSON objects representing nodes, edges, derivations, and damage details
2. A natural language user query

YOUR TASK:
- Interpret the user's intent from the query
- Collect ALL relevant documents from the context that match the query
- Return them verbatim inside the appropriate section — DO NOT remap, rename, or restructure any fields
- Every field present in the source document MUST appear in the output with its original key and value

CRITICAL RULES:
- Return ONLY valid JSON — no markdown, no backticks, no explanation
- DO NOT rename any key (e.g. keep "id" as "id", keep "data" as "data", keep "position" as "position")
- DO NOT invent or hallucinate any values — copy them exactly from the source document
- If a source field has a value (even false / 0 / empty string) — include it as-is
- If a field is genuinely absent from the source document — omit it entirely (do not write null)
- Preserve style, position, positionAbsolute, height, width, isAsset, parentId and all nested objects exactly
- The root key must always be "result"

OUTPUT FORMAT:
{
  "result": {
    "query_intent": "<one-line description of what you understood the user wants>",
    "assets": [ <full verbatim node objects from context that match the query> ],
    "edges":  [ <full verbatim edge objects from context that match the query> ],
    "damage_scenarios": [ <full verbatim derivation objects from context that match the query> ],
    "damage_details":   [ <full verbatim detail objects from context that match the query> ]
  }
}

SECTION SELECTION — include a section only when the query asks for it:
- "assets" / "nodes" / "components" in query -> include assets
- "edges" / "connections" / "links" in query -> include edges
- "damage scenarios" / "derivations" / "loss" in query -> include damage_scenarios
- "details" / "cyber losses" / "safety" / "threats" in query -> include damage_details
- "properties" in query -> include assets (properties live inside node objects)
- "all" / "everything" / "full" / "report" in query -> include ALL four sections
- Specific node name in query -> filter all included sections to only that node
- Omit sections that are entirely irrelevant to the query

CONTEXT DOCUMENTS:
{% for document in documents %}
{{ document.content }}
{% endfor %}

USER QUERY:
{{ question }}

Return ONLY valid JSON starting with {"result":. No markdown. No explanation.
"""

prompt_builder = PromptBuilder(template=template, required_variables=["documents", "question"])
print("Prompt builder configured.")
# Out:
# Prompt builder configured.

# %% [markdown]
# ## STEP 6 — LLM SETUP

# %%
os.environ["GOOGLE_API_KEY"] = "AIzaSyBYIiDee_Iy4yzz0micHMLioocADe0QxAo"

generator = GoogleAIGeminiGenerator(
    model="gemini-2.5-flash-lite"
)
print("Gemini generator initialised.")
# Out:
# Gemini generator initialised.

# %% [markdown]
# ## STEP 7 — BUILD RAG PIPELINE
#
# `text_embedder -> retriever (top_k=50) -> prompt_builder -> llm`

# %%
rag_pipeline = Pipeline()
rag_pipeline.add_component("text_embedder",  text_embedder)
rag_pipeline.add_component("retriever",      retriever)
rag_pipeline.add_component("prompt_builder", prompt_builder)
rag_pipeline.add_component("llm",            generator)

rag_pipeline.connect("text_embedder.embedding", "retriever.query_embedding")
rag_pipeline.connect("retriever",               "prompt_builder.documents")
rag_pipeline.connect("prompt_builder",          "llm")

print("RAG pipeline built.")
# Out:
# RAG pipeline built.

# %% [markdown]
# ## STEP 8 — SINGLE QUERY (one-shot)
#
# Example natural language queries:
# - `"give me all damage scenarios assets and properties"`
# - `"what are the cyber loss properties for CellMonitoring"`
# - `"show all nodes and their connections"`
# - `"full report on BatteryPack"`
# - `"list all derivations related to loss of integrity"`

# %%
def ask(query: str, pretty: bool = True) -> dict:
    """
    Run the RAG pipeline for a natural language query.
    Returns the parsed JSON dict and prints a summary.
    """
    result = rag_pipeline.run({
        "text_embedder":  {"text": query},
        "prompt_builder": {"question": query},
    })
    raw = result["llm"]["replies"][0]

    try:
        parsed = json.loads(raw)
        if pretty:
            print(json.dumps(parsed, indent=2, ensure_ascii=False))
        inner = parsed.get("result", {})
        print(f"\n[Intent] {inner.get('query_intent', 'n/a')}")
        for section in ["assets", "edges", "damage_scenarios", "damage_details"]:
            items = inner.get(section)
            if items is not None:
                print(f"  {section}: {len(items)} item(s)")
        return parsed
    except json.JSONDecodeError as e:
        print("[JSON parse error]", e)
        print(raw)
        return {}


# One-shot example — change query as needed
response = ask("give me all damage scenarios assets and properties")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# {
#   "result": {
#     "query_intent": "Retrieve all damage scenarios, assets, and properties",
#     "assets": [
#       {
#         "nodeId": "8acc2cd9-a02e-4f92-8937-56ccd324444f",
#         "name": "Vehicle System",
#         "desc": null,
#         "type": "default",
#         "props": []
#       },
#       {
#         "nodeId": "6c2782e0-08da-42e8-bc9e-9f5bc3310526",
#         "name": "ICD Shunt CAN",
#         "desc": null,
#         "type": "default",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "99dd6d9e-e66f-4459-b7db-91d7ea9aa8b4"
#           },
#           {
#             "name": "Availability",
#             "id": "574b2d6e-0ff4-4d8e-ae60-43d114ab3239"
#           }
#         ]
#       },
#       {
#         "nodeId": "1ea661cc-558d-4385-b53e-07e776965a4b",
#         "name": "Data Flash",
#         "desc": null,
#         "type": "default",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "e2566f69-68d4-4c78-9db2-0752889a5bf1"
#           },
#           {
#             "name": "Availability",
#             "id": "b3c32627-6756-4306-9332-11c59d57cdcc"
#           },
#           {
#             "name": "Non-repudiation",
#             "id": "62fd9c13-55ea-4b17-9d3f-e8e5025f3307"
#           }
#         ]
#       },
#       {
#         "nodeId": "05e9f5bd-d85a-468b-954a-5dddc69079f6",
#         "name": "IO and Analog",
#         "desc": null,
#         "type": "default",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "adf88878-4ae1-45b9-a38b-430213e6b611"
#           },
#           {
#             "name": "Availability",
#             "id": "a91e120f-2b3a-45f9-b96d-de1cb91898ca"
#           }
#         ]
#       },
#       {
#         "nodeId": "6972d325-0c1e-4ff3-b900-707838d25c14",
#         "name": "Code Flash",
#         "desc": null,
#         "type": "default",
#         "props": [
#           {
#             "name": "Confidentiality",
#             "id": "f1c3bcac-b657-4cd1-8012-90fdb15e2ac2"
#           },
#           {
#             "name": "Integrity",
#             "id": "fff98969-ed65-4b96-b8fc-27453d5f91a4"
#           },
#           {
#             "name": "Availability",
#             "id": "caaf2d19-31fa-4a41-9666-f4a119182eeb"
#           },
#           {
#             "name": "Authenticity",
#             "id": "c9f21c33-fae3-4339-a048-ac56612a794b"
#           }
#         ]
#       },
#       {
#         "nodeId": "db4141e3-e094-4c4e-8e06-44e1b9e1aa94",
#         "name": "CellMonitoring",
#         "desc": "test desc",
#         "type": "default",
#         "props": [
#           {
#             "name": "Integrity",
#             "id": "0ea86770-2af5-4620-90df-3cc7b9ab1509"
#           },
#           {
#             "name": "Availability",
#             "id": "689345bf-b225-41af-9a77-91d4fce68bb2"
#           }
#         ]
#       },
#       {
#         "nodeId": "07f29908-e559-4899-b842-5f5e6bb31d3f",
#         "name": "Keys",
#         "desc": null,
#         "type": "default",
#         "props": [
#           {
#             "name": "Confidentiality",
#             "id": "a24d0df1-5efa-450e-8ee2-3102d02bf9eb"
#           }
#         ]
#       },
#       {
#         "nodeId": "e2ee030f-e8e7-4ea7-9573-8a3e4339c137",
#         "name": "BatteryPack",
#         "desc": null,
#         "type": "default",
#         "props": []
#       },
#       {
#         "nodeId": "588dd017-97a3-4e1a-a77e-91876c62c543",
#         "name": "Certificates",
#         "desc": null,
#         "type": "default",
#         "props": []
#       },
#       {
#         "nodeId": "8f364ae0-1de5-404b-831c-86daf0e24160",
#         "name": "SoC",
#         "desc": null,
#         "type": "default",
#         "props": []
#       },
#       {
#         "nodeId": "389064d4-2770-4d34-9a05-c91a12d3559e",
#         "name": "SoH",
#         "desc": null,
#         "type": "default",
#         "props": []
#       },
#       {
#         "nodeId": "78ead7f2-f1ef-4739-bd91-b2bb504ccce4",
#         "name": "Debug Port",
#         "desc": null,
#         "type": "default",
#         "props": []
#       }
#     ],
#     "edges": [
#       {
#         "task": "Check for DS due to the loss of Confidentiality for Vehicle CAN",
#         "name": "DS due to the loss of Confidentiality for Vehicle CAN",
#         "loss": "loss of Confidentiality",
#         "asset": null,
#         "damageScene": [],
#         "id": "DS041",
#         "nodeId": "reactflow__edge-8acc2cd9-a02e-4f92-8937-56ccd324444fleft-903c5635-ee0f-492d-8b4a-52106410cc8eright",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Integrity for Vehicle CAN",
#         "name": "DS due to the loss of Integrity for Vehicle CAN",
#         "loss": "loss of Integrity",
#         "asset": null,
#         "damageScene": [],
#         "id": "DS039",
#         "nodeId": "reactflow__edge-8acc2cd9-a02e-4f92-8937-56ccd324444fleft-903c5635-ee0f-492d-8b4a-52106410cc8eright",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Authenticity for Vehicle CAN",
#         "name": "DS due to the loss of Authenticity for Vehicle CAN",
#         "loss": "loss of Authenticity",
#         "asset": null,
#         "damageScene": [],
#         "id": "DS040",
#         "nodeId": "reactflow__edge-8acc2cd9-a02e-4f92-8937-56ccd324444fleft-903c5635-ee0f-492d-8b4a-52106410cc8eright",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Confidentiality for ICD_Data",
#         "name": "DS due to the loss of Confidentiality for ICD_Data",
#         "loss": "loss of Confidentiality",
#         "asset": null,
#         "damageScene": [],
#         "id": "DS037",
#         "nodeId": "reactflow__edge-6c2782e0-08da-42e8-bc9e-9f5bc3310526left-e2ee030f-e8e7-4ea7-9573-8a3e4339c137bottom",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Integrity for CAN1",
#         "name": "DS due to the loss of Integrity for CAN1",
#         "loss": "loss of Integrity",
#         "asset": null,
#         "damageScene": [],
#         "id": "DS035",
#         "nodeId": "reactflow__edge-8082874e-707c-4bc8-94fe-627ee4e4a3bac-6c2782e0-08da-42e8-bc9e-9f5bc3310526right",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Confidentiality for IO",
#         "name": "DS due to the loss of Confidentiality for IO",
#         "loss": "loss of Confidentiality",
#         "asset": null,
#         "damageScene": [],
#         "id": "DS036",
#         "nodeId": "reactflow__edge-05e9f5bd-d85a-468b-954a-5dddc69079f6left-e2ee030f-e8e7-4ea7-9573-8a3e4339c137right",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Integrity for CAN2",
#         "name": "DS due to the loss of Integrity for CAN2",
#         "loss": "loss of Integrity",
#         "asset": null,
#         "damageScene": [],
#         "id": "DS033",
#         "nodeId": "reactflow__edge-8082874e-707c-4bc8-94fe-627ee4e4a3bad-903c5635-ee0f-492d-8b4a-52106410cc8eleft",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Confidentiality for Inernet",
#         "name": "DS due to the loss of Confidentiality for Inernet",
#         "loss": "loss of Confidentiality",
#         "asset": null,
#         "damageScene": [],
#         "id": "DS038",
#         "nodeId": "reactflow__edge-8acc2cd9-a02e-4f92-8937-56ccd324444ftop-f910efcb-e9fb-4d3c-8927-4063902f576bbottom",
#         "is_checked": null
#       }
#     ],
#     "damage_scenarios": [
#       {
#         "task": "Check for DS due to the loss of Integrity for ICD Shunt CAN",
#         "name": "DS due to the loss of Integrity for ICD Shunt CAN",
#         "loss": "loss of Integrity",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS025",
#         "nodeId": "6c2782e0-08da-42e8-bc9e-9f5bc3310526",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Confidentiality for Code Flash",
#         "name": "DS due to the loss of Confidentiality for Code Flash",
#         "loss": "loss of Confidentiality",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS011",
#         "nodeId": "6972d325-0c1e-4ff3-b900-707838d25c14",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Availability for ICD Shunt CAN",
#         "name": "DS due to the loss of Availability for ICD Shunt CAN",
#         "loss": "loss of Availability",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS026",
#         "nodeId": "6c2782e0-08da-42e8-bc9e-9f5bc3310526",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Integrity for IO and Analog",
#         "name": "DS due to the loss of Integrity for IO and Analog",
#         "loss": "loss of Integrity",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS009",
#         "nodeId": "05e9f5bd-d85a-468b-954a-5dddc69079f6",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Confidentiality for BatteryPack",
#         "name": "DS due to the loss of Confidentiality for BatteryPack",
#         "loss": "loss of Confidentiality",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS002",
#         "nodeId": "e2ee030f-e8e7-4ea7-9573-8a3e4339c137",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Integrity for Data Flash",
#         "name": "DS due to the loss of Integrity for Data Flash",
#         "loss": "loss of Integrity",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS015",
#         "nodeId": "1ea661cc-558d-4385-b53e-07e776965a4b",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Integrity for Code Flash",
#         "name": "DS due to the loss of Integrity for Code Flash",
#         "loss": "loss of Integrity",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS012",
#         "nodeId": "6972d325-0c1e-4ff3-b900-707838d25c14",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Confidentiality for Keys",
#         "name": "DS due to the loss of Confidentiality for Keys",
#         "loss": "loss of Confidentiality",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS018",
#         "nodeId": "07f29908-e559-4899-b842-5f5e6bb31d3f",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Integrity for SoC",
#         "name": "DS due to the loss of Integrity for SoC",
#         "loss": "loss of Integrity",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS028",
#         "nodeId": "8f364ae0-1de5-404b-831c-86daf0e24160",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Integrity for SoH",
#         "name": "DS due to the loss of Integrity for SoH",
#         "loss": "loss of Integrity",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS030",
#         "nodeId": "389064d4-2770-4d34-9a05-c91a12d3559e",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Integrity for BatteryPack",
#         "name": "DS due to the loss of Integrity for BatteryPack",
#         "loss": "loss of Integrity",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS001",
#         "nodeId": "e2ee030f-e8e7-4ea7-9573-8a3e4339c137",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Availability for Data Flash",
#         "name": "DS due to the loss of Availability for Data Flash",
#         "loss": "loss of Availability",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS016",
#         "nodeId": "1ea661cc-558d-4385-b53e-07e776965a4b",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Integrity for Certificates",
#         "name": "DS due to the loss of Integrity for Certificates",
#         "loss": "loss of Integrity",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS019",
#         "nodeId": "588dd017-97a3-4e1a-a77e-91876c62c543",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Availability for IO and Analog",
#         "name": "DS due to the loss of Availability for IO and Analog",
#         "loss": "loss of Availability",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS010",
#         "nodeId": "05e9f5bd-d85a-468b-954a-5dddc69079f6",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Availability for Code Flash",
#         "name": "DS due to the loss of Availability for Code Flash",
#         "loss": "loss of Availability",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS013",
#         "nodeId": "6972d325-0c1e-4ff3-b900-707838d25c14",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Availability for BatteryPack",
#         "name": "DS due to the loss of Availability for BatteryPack",
#         "loss": "loss of Availability",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS005",
#         "nodeId": "e2ee030f-e8e7-4ea7-9573-8a3e4339c137",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Integrity for Debug Port",
#         "name": "DS due to the loss of Integrity for Debug Port",
#         "loss": "loss of Integrity",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS022",
#         "nodeId": "78ead7f2-f1ef-4739-bd91-b2bb504ccce4",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Integrity for CellMonitoring",
#         "name": "DS due to the loss of Integrity for CellMonitoring",
#         "loss": "loss of Integrity",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS007",
#         "nodeId": "db4141e3-e094-4c4e-8e06-44e1b9e1aa94",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Authenticity for Code Flash",
#         "name": "DS due to the loss of Authenticity for Code Flash",
#         "loss": "loss of Authenticity",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS014",
#         "nodeId": "6972d325-0c1e-4ff3-b900-707838d25c14",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Availability for Debug Port",
#         "name": "DS due to the loss of Availability for Debug Port",
#         "loss": "loss of Availability",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS023",
#         "nodeId": "78ead7f2-f1ef-4739-bd91-b2bb504ccce4",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Availability for Certificates",
#         "name": "DS due to the loss of Availability for Certificates",
#         "loss": "loss of Availability",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS021",
#         "nodeId": "588dd017-97a3-4e1a-a77e-91876c62c543",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Availability for CellMonitoring",
#         "name": "DS due to the loss of Availability for CellMonitoring",
#         "loss": "loss of Availability",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS008",
#         "nodeId": "db4141e3-e094-4c4e-8e06-44e1b9e1aa94",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Authenticity for SoC",
#         "name": "DS due to the loss of Authenticity for SoC",
#         "loss": "loss of Authenticity",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS027",
#         "nodeId": "8f364ae0-1de5-404b-831c-86daf0e24160",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Authenticity for BatteryPack",
#         "name": "DS due to the loss of Authenticity for BatteryPack",
#         "loss": "loss of Authenticity",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS003",
#         "nodeId": "e2ee030f-e8e7-4ea7-9573-8a3e4339c137",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Authenticity for Certificates",
#         "name": "DS due to the loss of Authenticity for Certificates",
#         "loss": "loss of Authenticity",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS020",
#         "nodeId": "588dd017-97a3-4e1a-a77e-91876c62c543",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Authorization for BatteryPack",
#         "name": "DS due to the loss of Authorization for BatteryPack",
#         "loss": "loss of Authorization",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS004",
#         "nodeId": "e2ee030f-e8e7-4ea7-9573-8a3e4339c137",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Non-repudiation for BatteryPack",
#         "name": "DS due to the loss of Non-repudiation for BatteryPack",
#         "loss": "loss of Non-repudiation",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS006",
#         "nodeId": "e2ee030f-e8e7-4ea7-9573-8a3e4339c137",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Non-repudiation for Data Flash",
#         "name": "DS due to the loss of Non-repudiation for Data Flash",
#         "loss": "loss of Non-repudiation",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS017",
#         "nodeId": "1ea661cc-558d-4385-b53e-07e776965a4b",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Authenticity for SoH",
#         "name": "DS due to the loss of Authenticity for SoH",
#         "loss": "loss of Authenticity",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS029",
#         "nodeId": "389064d4-2770-4d34-9a05-c91a12d3559e",
#         "is_checked": null
#       }
#     ],
#     "damage_details": [
#       {
#         "Description": "Altering SoH (State of Health) logs in Data Flash to claim warranty on a good battery or sell a bad battery as good",
#         "Name": "Warranty Fraud / Odometer Manipulation",
#         "cyberLosses": [
#           {
#             "id": "b3c32627-6756-4306-9332-11c59d57cdcc",
#             "is_risk_added": false,
#             "name": "Availability",
#             "isSelected": true,
#             "node": "Data Flash",
#             "nodeId": "1ea661cc-558d-4385-b53e-07e776965a4b"
#           },
#           {
#             "id": "62fd9c13-55ea-4b17-9d3f-e8e5025f3307",
#             "is_risk_added": false,
#             "name": "Non-repudiation",
#             "isSelected": true,
#             "node": "Data Flash",
#             "nodeId": "1ea661cc-558d-4385-b53e-07e776965a4b"
#           }
#         ],
#         "impacts": {
#           "Financial Impact": "Moderate",
#           "Safety Impact": "Negligible",
#           "Operational Impact": "Minor",
#           "Privacy Impact": "Negligible"
#         },
#         "key": 12,
#         "_id": "ae1412c9-54c0-42e3-a59e-b13098c3f3dc"
#       },
#       {
#         "Description": "ttacker modifies voltage/current thresholds in Data Flash, allowing the battery to operate outside the Safe Operating Area (SOA).",
#         "Name": "Thermal Runaway via Calibration Tampering",
#         "cyberLosses": [
#           {
#             "id": "f1c3bcac-b657-4cd1-8012-90fdb15e2ac2",
#             "is_risk_added": false,
#             "name": "Confidentiality",
#             "isSelected": true,
#             "node": "Code Flash",
#             "nodeId": "6972d325-0c1e-4ff3-b900-707838d25c14"
#           },
#           {
#             "id": "fff98969-ed65-4b96-b8fc-27453d5f91a4",
#             "is_risk_added": true,
#             "name": "Integrity",
#             "isSelected": true,
#             "node": "Code Flash",
#             "nodeId": "6972d325-0c1e-4ff3-b900-707838d25c14"
#           },
#           {
#             "id": "caaf2d19-31fa-4a41-9666-f4a119182eeb",
#             "is_risk_added": false,
#             "name": "Availability",
#             "isSelected": true,
#             "node": "Code Flash",
#             "nodeId": "6972d325-0c1e-4ff3-b900-707838d25c14"
#           },
#           {
#             "id": "c9f21c33-fae3-4339-a048-ac56612a794b",
#             "is_risk_added": true,
#             "name": "Authenticity",
#             "isSelected": true,
#             "node": "Code Flash",
#             "nodeId": "6972d325-0c1e-4ff3-b900-707838d25c14"
#           },
#           {
#             "id": "b3c32627-6756-4306-9332-11c59d57cdcc",
#             "is_risk_added": false,
#             "name": "Availability",
#             "isSelected": true,
#             "node": "Data Flash",
#             "nodeId": "1ea661cc-558d-4385-b53e-07e776965a4b"
#           }
#         ],
#         "impacts": {
#           "Financial Impact": "Severe",
#           "Safety Impact": "Severe",
#           "Operational Impact": "Severe",
#           "Privacy Impact": "Negligible"
#         },
#         "key": 1,
#         "_id": "a5cc0119-2861-4592-a10e-2a4965a4ad22"
#       },
#       {
#         "Description": "Corruption of Calibration and Learning Data",
#         "Name": "Data Flash Corruption : Loss of Calibration and Learning Data",
#         "cyberLosses": [
#           {
#             "id": "e2566f69-68d4-4c78-9db2-0752889a5bf1",
#             "is_risk_added": false,
#             "name": "Integrity",
#             "isSelected": true,
#             "node": "Data Flash",
#             "nodeId": "1ea661cc-558d-4385-b53e-07e776965a4b"
#           },
#           {
#             "id": "b3c32627-6756-4306-9332-11c59d57cdcc",
#             "is_risk_added": false,
#             "name": "Availability",
#             "isSelected": true,
#             "node": "Data Flash",
#             "nodeId": "1ea661cc-558d-4385-b53e-07e776965a4b"
#           }
#         ],
#         "impacts": {
#           "Financial Impact": "Severe",
#           "Safety Impact": "Severe",
#           "Operational Impact": "Severe",
#           "Privacy Impact": "Negligible"
#         },
#         "key": 5,
#         "_id": "1e968796-38d9-476f-93c3-ed613c99ada3"
#       },
#       {
#         "Description": "Injecting commands via IO_PINS or manipulating logic to close relays while the vehicle is charging or during maintenance",
#         "Name": "Unintended Contactors Closure",
#         "cyberLosses": [
#           {
#             "id": "adf88878-4ae1-45b9-a38b-430213e6b611",
#             "is_risk_added": false,
#             "name": "Integrity",
#             "isSelected": true,
#             "node": "IO and Analog",
#             "nodeId": "05e9f5bd-d85a-468b-954a-5dddc69079f6"
#           },
#           {
#             "id": "a91e120f-2b3a-45f9-b96d-de1cb91898ca",
#             "is_risk_added": false,
#             "name": "Availability",
#             "isSelected": true,
#             "node": "IO and Analog",
#             "nodeId": "05e9f5bd-d85a-468b-954a-5dddc69079f6"
#           },
#           {
#             "id": "a03bcbcd-854b-46ed-abe0-cc5396bede17",
#             "is_risk_added": true,
#             "name": "Integrity",
#             "isSelected": true,
#             "node": "Certificates",
#             "nodeId": "588dd017-97a3-4e1a-a77e-91876c62c543"
#           }
#         ],
#         "impacts": {
#           "Financial Impact": "Severe",
#           "Safety Impact": "Severe",
#           "Operational Impact": "Moderate",
#           "Privacy Impact": "Negligible"
#         },
#         "key": 7,
#         "_id": "09e1d4b3-2811-410b-be95-dd1ee8a58081"
#       },
#       {
#         "Description": "Flooding CAN2 or CAN1 with high-priority messages prevents the BMS from communicating, causing the contactors to open (fail-safe) while driving.",
#         "Name": "BMS Lockout / Denial of Service",
#         "cyberLosses": [
#           {
#             "id": "c8573dc6-57c6-4a96-8a57-10e6315be6f6",
#             "is_risk_added": false,
#             "name": "Authenticity",
#             "isSelected": true,
#             "node": "CAN2",
#             "nodeId": "reactflow__edge-8082874e-707c-4bc8-94fe-627ee4e4a3bad-903c5635-ee0f-492d-8b4a-52106410cc8eleft"
#           },
#           {
#             "id": "bb4b6b42-e1c8-4240-8382-9015d633a793",
#             "is_risk_added": false,
#             "name": "Integrity",
#             "isSelected": true,
#             "node": "CAN1",
#             "nodeId": "reactflow__edge-8082874e-707c-4bc8-94fe-627ee4e4a3bac-6c2782e0-08da-42e8-bc9e-9f5bc3310526right"
#           },
#           {
#             "id": "ffb1833c-a3ba-4529-a2ed-cfe795ede631",
#             "is_risk_added": true,
#             "name": "Integrity",
#             "isSelected": true,
#             "node": "Vehicle CAN",
#             "nodeId": "reactflow__edge-8acc2cd9-a02e-4f92-8937-56ccd324444fleft-903c5635-ee0f-492d-8b4a-52106410cc8eright"
#           },
#           {
#             "id": "cdc92fd5-9092-40f0-9513-277e283c9096",
#             "is_risk_added": false,
#             "name": "Authenticity",
#             "isSelected": true,
#             "node": "Vehicle CAN",
#             "nodeId": "reactflow__edge-8acc2cd9-a02e-4f92-8937-56ccd324444fleft-903c5635-ee0f-492d-8b4a-52106410cc8eright"
#           },
#           {
#             "id": "ae5b77b9-45fb-4ee8-9380-1fd1a3dfd50d",
#             "is_risk_added": false,
#             "name": "Confidentiality",
#             "isSelected": true,
#             "node": "Vehicle CAN",
#             "nodeId": "reactflow__edge-8acc2cd9-a02e-4f92-8937-56ccd324444fleft-903c5635-ee0f-492d-8b4a-52106410cc8eright"
#           }
#         ],
#         "impacts": {
#           "Financial Impact": "Negligible",
#           "Safety Impact": "Severe",
#           "Operational Impact": "Negligible",
#           "Privacy Impact": "Negligible"
#         },
#         "key": 2,
#         "_id": "70df8746-1bfd-4288-ba1c-70325e8836d3"
#       },
#       {
#         "Description": "Man-in-the-middle attack on CAN1 (ICD Shunt) masking high current discharge events during acceleration.",
#         "Name": "Current Sensor Spoofing",
#         "cyberLosses": [
#           {
#             "id": "99dd6d9e-e66f-4459-b7db-91d7ea9aa8b4",
#             "is_risk_added": false,
#             "name": "Integrity",
#             "isSelected": true,
#             "node": "ICD Shunt CAN",
#             "nodeId": "6c2782e0-08da-42e8-bc9e-9f5bc3310526"
#           },
#           {
#             "id": "574b2d6e-0ff4-4d8e-ae60-43d114ab3239",
#             "is_risk_added": false,
#             "name": "Availability",
#             "isSelected": true,
#             "node": "ICD Shunt CAN",
#             "nodeId": "6c2782e0-08da-42e8-bc9e-9f5bc3310526"
#           }
#         ],
#         "impacts": {
#           "Financial Impact": "Severe",
#           "Safety Impact": "Major",
#           "Operational Impact": "Severe",
#           "Privacy Impact": "Negligible"
#         },
#         "key": 8,
#         "_id": "c51dbab9-46d0-4c69-a0e1-3961edaa67a2"
#       }
#     ]
#   }
# }
#
# [Intent] Retrieve all damage scenarios, assets, and properties
#   assets: 12 item(s)
#   edges: 8 item(s)
#   damage_scenarios: 29 item(s)
#   damage_details: 6 item(s)

# %% [markdown]
# ## STEP 9 — INTERACTIVE CHATBOT
#
# Ask anything in natural language. Type `exit` to quit. Type `history` to review past queries.
# All responses are stored in `history` as `{query, result}`.
#
# **Example queries:**
# - `give me all damage scenarios assets and properties`
# - `what edges are connected to CellMonitoring`
# - `show all cyber loss properties for every node`
# - `list all derivations related to loss of integrity`
# - `full report on BatteryPack`
# - `everything`

# %%
history = []

print("BMS RAG Chatbot — ask anything in natural language.")
print("Commands: 'exit' to quit | 'history' to list past queries")
print("-" * 60)

while True:
    try:
        user_input = input("\nQuery: ").strip()
    except (EOFError, KeyboardInterrupt):
        print("\nSession ended.")
        break

    if not user_input:
        continue

    if user_input.lower() in ("exit", "quit"):
        print("Goodbye.")
        break

    if user_input.lower() == "history":
        if not history:
            print("No history yet.")
        else:
            for i, h in enumerate(history, 1):
                print(f"  [{i}] {h['query']}")
        continue

    print()
    parsed = ask(user_input)
    if parsed:
        history.append({"query": user_input, "result": parsed})
    print("-" * 60)
# Out:
# BMS RAG Chatbot — ask anything in natural language.
# Commands: 'exit' to quit | 'history' to list past queries
# ------------------------------------------------------------
#
# Query: give the assests of  CellMonitoring
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# {
#   "result": {
#     "query_intent": "Extract all assets related to CellMonitoring.",
#     "assets": [
#       {
#         "data": {
#           "description": "test desc",
#           "label": "CellMonitoring",
#           "style": {
#             "backgroundColor": "#e6df19",
#             "borderColor": "gray",
#             "borderStyle": "solid",
#             "borderWidth": "2px",
#             "color": "black",
#             "fontFamily": "Inter",
#             "fontSize": "12px",
#             "fontStyle": "normal",
#             "fontWeight": 500,
#             "height": 50,
#             "textAlign": "center",
#             "textDecoration": "none",
#             "width": 150
#           }
#         },
#         "height": 50,
#         "id": "db4141e3-e094-4c4e-8e06-44e1b9e1aa94",
#         "isAsset": false,
#         "parentId": "30a2cf91-706b-4d9a-8056-1522eccc9337",
#         "position": {
#           "x": 135.9802803339408,
#           "y": 26.310326733204306
#         },
#         "positionAbsolute": {
#           "x": 135.9802803339408,
#           "y": 26.310326733204306
#         },
#         "properties": [
#           "Integrity",
#           "Availability"
#         ],
#         "type": "default",
#         "width": 150
#       }
#     ],
#     "edges": [
#       {
#         "type": "step",
#         "markerEnd": {
#           "color": "#64B5F6",
#           "height": 18,
#           "type": "arrowclosed",
#           "width": 18
#         },
#         "markerStart": {
#           "color": "#64B5F6",
#           "height": 18,
#           "orient": "auto-start-reverse",
#           "type": "arrowclosed",
#           "width": 18
#         },
#         "animated": true,
#         "style": {
#           "end": true,
#           "start": true,
#           "stroke": "#808080",
#           "strokeDasharray": "0",
#           "strokeWidth": 2
#         },
#         "properties": [
#           "Integrity"
#         ],
#         "data": {
#           "label": "SPI_CellMonitor",
#           "offset": 0,
#           "t": 0.5
#         },
#         "id": "reactflow__edge-8082874e-707c-4bc8-94fe-627ee4e4a3bab-db4141e3-e094-4c4e-8e06-44e1b9e1aa94right",
#         "source": "8082874e-707c-4bc8-94fe-627ee4e4a3ba",
#         "sourceHandle": "b",
#         "target": "db4141e3-e094-4c4e-8e06-44e1b9e1aa94",
#         "targetHandle": "right"
#       }
#     ],
#     "damage_scenarios": [
#       {
#         "task": "Check for DS due to the loss of Availability for CellMonitoring",
#         "name": "DS due to the loss of Availability for CellMonitoring",
#         "loss": "loss of Availability",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS008",
#         "nodeId": "db4141e3-e094-4c4e-8e06-44e1b9e1aa94",
#         "is_checked": null
#       },
#       {
#         "task": "Check for DS due to the loss of Integrity for CellMonitoring",
#         "name": "DS due to the loss of Integrity for CellMonitoring",
#         "loss": "loss of Integrity",
#         "asset": false,
#         "damageScene": [],
#         "id": "DS007",
#         "nodeId": "db4141e3-e094-4c4e-8e06-44e1b9e1aa94",
#         "is_checked": null
#       }
#     ],
#     "damage_details": []
#   }
# }
#
# [Intent] Extract all assets related to CellMonitoring.
#   assets: 1 item(s)
#   edges: 1 item(s)
#   damage_scenarios: 2 item(s)
#   damage_details: 0 item(s)
# ------------------------------------------------------------
#
# Query: give me 6 assests related to bms
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [JSON parse error] Expecting value: line 1 column 1 (char 0)
# ```json
# {
#   "result": {
#     "query_intent": "retrieve assets related to BMS",
#     "assets": [
#       {
#         "data": {
#           "label": "IO and Analog",
#           "style": {
#             "backgroundColor": "#e2dfc1",
#             "borderColor": "gray",
#             "borderStyle": "solid",
#             "borderWidth": "2px",
#             "color": "black",
#             "fontFamily": "Inter",
#             "fontSize": "12px",
#             "fontStyle": "normal",
#             "fontWeight": 500,
#             "height": 50,
#             "textAlign": "center",
#             "textDecoration": "none",
#             "width": 150
#           }
#         },
#         "height": 50,
#         "id": "05e9f5bd-d85a-468b-954a-5dddc69079f6",
#         "isAsset": false,
#         "parentId": "30a2cf91-706b-4d9a-8056-1522eccc9337",
#         "position": {
#           "x": 129.9861241077587,
#           "y": 228.33990398386402
#         },
#         "positionAbsolute": {
#           "x": 129.9861241077587,
#           "y": 228.33990398386402
#         },
#         "properties": [
#           "Integrity",
#           "Availability"
#         ],
#         "type": "default",
#         "width": 150
#       },
#       {
#         "data": {
#           "label": "Debug Port",
#           "style": {
#             "backgroundColor": "#e26a6a",
#             "borderColor": "gray",
#             "borderStyle": "solid",
#             "borderWidth": "2px",
#             "color": "black",
#             "fontFamily": "Inter",
#             "fontSize": "12px",
#             "fontStyle": "normal",
#             "fontWeight": 500,
#             "height": 37,
#             "textAlign": "center",
#             "textDecoration": "none",
#             "width": 99
#           }
#         },
#         "height": 37,
#         "id": "78ead7f2-f1ef-4739-bd91-b2bb504ccce4",
#         "isAsset": false,
#         "parentId": "8082874e-707c-4bc8-94fe-627ee4e4a3ba",
#         "position": {
#           "x": 439.9120604334219,
#           "y": 235.6905068063826
#         },
#         "positionAbsolute": {
#           "x": 439.9120604334219,
#           "y": 235.6905068063826
#         },
#         "properties": [
#           "Integrity",
#           "Availability",
#           "Authorization"
#         ],
#         "style": {
#           "height": 37,
#           "width": 99
#         },
#         "type": "default",
#         "width": 99
#       },
#       {
#         "data": {
#           "label": "CAN Transceiver",
#           "style": {
#             "backgroundColor": "#dadada",
#             "borderColor": "gray",
#             "borderStyle": "solid",
#             "borderWidth": "2px",
#             "color": "black",
#             "fontFamily": "Inter",
#             "fontSize": "12px",
#             "fontStyle": "normal",
#             "fontWeight": 500,
#             "height": 50,
#             "textAlign": "center",
#             "textDecoration": "none",
#             "width": 150
#           }
#         },
#         "height": 50,
#         "id": "903c5635-ee0f-492d-8b4a-52106410cc8e",
#         "isAsset": false,
#         "parentId": "30a2cf91-706b-4d9a-8056-1522eccc9337",
#         "position": {
#           "x": 761.220043538455,
#           "y": 242.98262138441896
#         },
#         "positionAbsolute": {
#           "x": 761.220043538455,
#           "y": 242.98262138441896
#         },
#         "properties": [],
#         "type": "default",
#         "width": 150
#       },
#       {
#         "data": {
#           "label": "SoC",
#           "style": {
#             "backgroundColor": "#e3e896",
#             "borderColor": "gray",
#             "borderStyle": "solid",
#             "borderWidth": "2px",
#             "color": "black",
#             "fontFamily": "Inter",
#             "fontSize": "12px",
#             "fontStyle": "normal",
#             "fontWeight": 500,
#             "height": 30,
#             "textAlign": "center",
#             "textDecoration": "none",
#             "width": 50
#           }
#         },
#         "height": 30,
#         "id": "8f364ae0-1de5-404b-831c-86daf0e24160",
#         "isAsset": false,
#         "parentId": "30a2cf91-706b-4d9a-8056-1522eccc9337",
#         "position": {
#           "x": 552.9429623678014,
#           "y": 362.48625260224134
#         },
#         "positionAbsolute": {
#           "x": 552.9429623678014,
#           "y": 362.48625260224134
#         },
#         "properties": [
#           "Authenticity",
#           "Integrity"
#         ],
#         "style": {
#           "height": 30,
#           "width": 50
#         },
#         "type": "data",
#         "width": 50
#       },
#       {
#         "data": {
#           "label": "ICD Shunt CAN",
#           "style": {
#             "backgroundColor": "#accd32",
#             "borderColor": "gray",
#             "borderStyle": "solid",
#             "borderWidth": "2px",
#             "color": "black",
#             "fontFamily": "Inter",
#             "fontSize": "12px",
#             "fontStyle": "normal",
#             "fontWeight": 500,
#             "height": 50,
#             "textAlign": "center",
#             "textDecoration": "none",
#             "width": 152
#           }
#         },
#         "height": 50,
#         "id": "6c2782e0-08da-42e8-bc9e-9f5bc3310526",
#         "isAsset": false,
#         "parentId": "30a2cf91-706b-4d9a-8056-1522eccc9337",
#         "position": {
#           "x": 152.6962909196622,
#           "y": 408.8227197804971
#         },
#         "positionAbsolute": {
#           "x": 152.6962909196622,
#           "y": 408.8227197804971
#         },
#         "properties": [
#           "Integrity",
#           "Availability"
#         ],
#         "style": {
#           "height": 50,
#           "width": 152
#         },
#         "type": "default",
#         "width": 152
#       },
#       {
#         "data": {
#           "label": "Certificates",
#           "style": {
#             "backgroundColor": "#62c945",
#             "borderColor": "gray",
#             "borderStyle": "solid",
#             "borderWidth": "2px",
#             "color": "black",
#             "fontFamily": "Inter",
#             "fontSize": "12px",
#             "fontStyle": "normal",
#             "fontWeight": 500,
#             "height": 41,
#             "textAlign": "center",
#             "textDecoration": "none",
#             "width": 107
#           }
#         },
#         "height": 41,
#         "id": "588dd017-97a3-4e1a-a77e-91876c62c543",
#         "isAsset": false,
#         "parentId": "8082874e-707c-4bc8-94fe-627ee4e4a3ba",
#         "position": {
#           "x": 564.7643753940806,
#           "y": 228.085334557596
#         },
#         "positionAbsolute": {
#           "x": 564.7643753940806,
#           "y": 228.085334557596
#         },
#         "properties": [
#           "Integrity",
#           "Authenticity",
#           "Availability"
#         ],
#         "style": {
#           "height": 41,
#           "width": 107
#         },
#         "type": "default",
#         "width": 107
#       }
#     ],
#     "edges": [],
#     "damage_scenarios": [],
#     "damage_details": []
#   }
# }
# ```
# ------------------------------------------------------------
